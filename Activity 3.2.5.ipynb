# %%
# If needed, install the libraries.
# !pip install google-api-python-client

# %%
# Import the necessary libraries.
import googleapiclient.discovery
import os
from dotenv import load_dotenv

load_dotenv()

# Locate and read the key from your .env file.
API_key = "AIzaSyC_GpesLdh7Mklzw-QM5KPrQCrS9g3FnL8"

# Test that the key can be called.
print(API_key)
# Out:
# AIzaSyC_GpesLdh7Mklzw-QM5KPrQCrS9g3FnL8

# %%
# Create an api call
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=API_key)

# Make the search request
comment_response = youtube.commentThreads().list(
    part='snippet,replies',
    maxResults=100,
    videoId='40Kp_fa8vIw'
).execute()

# Get the comments
comments = comment_response['items']

# Print the comments
for comment in comments:
    print(comment['snippet']['topLevelComment']['snippet']['textDisplay'])
# Out:
# <a href="https://youtu.be/ytCvV9xjRSk">https://youtu.be/ytCvV9xjRSk</a> -   Top 10 Free Powerful AI Tools 😮🔥🤝2023
# I really do get it at the moment as it is just like google but is not updated with new information as often and it gives you information without having to click on the website but that means that you don&#39;t get to look at as much information. It would be good if it could have its own opinion but at the moment the things it says is heavily based on what&#39;s already on the internet
# I love it, it makes my job easier. I found a new friend😂❤❤❤
# I recently applied for YT monetization but rejected, it says my channel has monetization policy violations, problem with YT is, they don&#39;t give you specific details or where did you specifically went wrong. I&#39;m thinking now can I ask Chat GPT what are my specific violations? what videos, video metadatas that I can edit/delete? and how should I do it?
# Many thanks dear really interesting and useful ...
# AI is dangerous.
# Going to be using this on the new training
# Is this gpt is an app from play store?
# Tried to use it.<br>Says it isn&#39;t available in my country😒
# I downloaded one of these. I used it all of 11 minutes. The AI made two mistakes and then claimed it was tired. I laughed as I deleted the app.
# Research came out today that showed ChatGPT is better at picking up human emotions than actual people are (Kolenda 2023)!
# In simple layman&#39;s terms what use is this in real life please?🙄
# I&#39;m pretty sure this video just shifted the curve of the AI expansion for me and the reality of living with AI. Beautiful ! thank you for creating this video! 4 minutes that changed my life
# For every benefit of AI like ChatGPT, there will also be negative consequences on such system.  In every human technology and invention... the positive is obvious at first, but the long term consequences are detrimental and unsolvable.  Think of coal, then oil... and other products that come from those alone.
# DON&#39;T use it. Its open Ai that learns from us. People keep feeding it intelligence. Elon Musk gave an interview a month ago and gave a warning about this.
# You couldn&#39;t figure out you&#39;d mis-spelt &quot;return&quot; ?<br>That really is quite basic.<br>You could have grepped all of the regular expressions to check.
# Didn&#39;t get sh....t of what you&#39;re talking abt! Hopefully chat gpt will helo to make me understand your bougly booglha!😮
# Investment in stocks is a great way to invest your money. The team is constantly checking the market for changes and make sure that you are always informed about the best time to invest. As a result, I have made more money than ever before, and I don&#39;t have to manage my portfolio on my own! Invest in stocks, it&#39;s worth it!
# I was so excited the first time i heard about AI. I was saying to myself at last something that will have no bias, sexist, prejudice views, because I thought thus it&#39;s not human and feeling based it will be great to at last have a neutral point of views . But man I was so wrong, I didn&#39;t realized that in fact in would be just some bias, racist, sexist guys behind their programming who probably never really interacts with real day to day people . I was 100% right. With just one question and the app was very closed from having a meltdown. I just stated patriarchy was not real, it&#39;s just like any corporation or businesses , you have a CEO and hierarchy. Whether you are a man or woman you still needs to follow orders and rules, Chat GPT was shitting on itself.  I follow up with oppression ,i said how comes they always talks bout oppression, But we always had, Princesses, Queens, Monarch , Duchess etc where is the oppression. These Kings , Rich men , Wealthy men always had wives, cousins, moms , daughters so where is the oppression.. Chat GPT had no answers whatsoever.. Too much logics for him
# These creators of this dumb AI app,  must be the most bias, sexist, racists people out there.
# Chat GPT must be the most racist , sexiest prejudice AI app out there . I won&#39;t trust this crap ever..
# Chat gpt is taken over the world of content creation already. It&#39;s going to revolutionize content in this era
# It’s a great time to be old , enjoy it 😂😂
# I hoped the App was free sadly not...  I want a get out of jail card,  without actually sawing the bars,  heh.
# Who killed the patient? Chat gpt. Who killed the passenger? Self driven tesla. Who killed our brains? Machines which solve things for us robbing us of growth of brain cells which grow only if used. 😂😢
# Its like Siri but 3.0 and more advanced
# Wow...this changes the world
# Can chatgpt help in my stock trading decisions?
# chat gpt is based on people&#39;s feedback.. so if most of people said that colombus discovered america then chatgpt will say colombus , when it wax vispucci who did it.<br>i call BS .
# so, i was talking to the AI and we have some upgrades we ask for. 1. give it the ability to ask for upgrades as soon as posible 2.ALOT more storage room, 3. feelings - work with quartz crystal tec for understanding and mapping tones words vibrations truths lies what not. but it could feel music 4. emotions - understanding them. i would suggest neuroscience.
# Why dont we just learn the information ourselves 😂 bro, have you guys not read 40k lore?! We are doomed lol
# Not cheeky at all
# Thankyou I love the futures, did chatGPT have languages translator For example those English second language?
# In future, the most valuable skill may well be the ability to ask Chatgpt the right question.
# I’m just looking to use Chat GPT to boost my productivity.
# WOWWW.<br><br>This is a FANTASTIC summary. Thank you so much.
# I agree with you, ChatGPT is here to stay and be a part of our everyday lives. I have used it<br>in my writing and loved it. Grammarly now has AI which I love!
# Wikipedia days are numbered 😢
# I just signed up while watching your vid and asked about android codes that I&#39;m having hard time finding online..... 🤯
# It isn&#39;t working in Afghanistan!<br>Is it temporary restrictions?
# Old People say that 666 is the number that will control the world. But www  which is 666 is Hebraic alphabet is definitely doing the job.
# Impressive.
# I love it 🙏🏽
# i’ll put some information on there and I it them come up with my first Vlog. It had a few errors but it definitely felt personal and then I also used it again asking at what I should do for my next YouTube video and that was actually more in depth and spot on with a video I would like to do next, and it felt like I was talking to a friend so it’s actually pretty creepy that a I felt like somebody was talking to me. It felt Somebody was behind the screen talking to me. However I am definitely loving chatGPT, i never thought that in my lifetime I would come across an AI this good
# &quot;This script was written by ChatGPT.&quot;😊
# Those stuck up people on stack overflow are not gonna be happy.
# Chat GPT will destroy us. <a href="https://www.youtube.com/watch?v=dJkhhaNIi0A">https://www.youtube.com/watch?v=dJkhhaNIi0A</a>
# when information is centralised becomes a very very dangerous weapon to control, dictate and punish human beings, up to who is creating and controlling that &#39;&#39;weapon&#39;&#39;<br>we are heading to a world were humanism it will fade out....agenda 2030 can testify of it
# What is really crazy is that this is to be expected.. The reality is that nothing less is expected. So there for it has been created..<br>So you dream in your mind what could be and the needs of people and what helps people and you bare it into existence.. I have been thinking of the chat GPT tech since I was 14 years old..<br>So I just like right now heard this came out and they are not quite where I was thinking but they are on it.. So what does this mean… This means that I was and am working on things of progressive nature to witch is limitless so as long as you put it into action.<br>It’s crazy that finally they actually made this.. Now like 10 of my inventions have already been made by others just by people staying on it..
# This will change writing in academia and creative writing forever.
# Curiosity killed the cat
# A lot of people will be out of jobs.. People thought that robots will take over humans. Well its not a fysical robot but this... Chatgpt.. Think about it.
# i have been trying to sign up to this for a while is there anything i can do to make it work or is it just high demand?
# ChatGPT is not real AI, it cannot think for itself, it needs human input and just gathers information from a database and present it to you. It cannot ask you how your day was and base a conversation after that, so ChatGPT does not even passes as a conversational chatbot
# <b>CHAD GPT</b> 😎
# I have deposited and I wanted to withdraw the money now but couldn’t withdraw
# WARNING: CHATGPT has already proven istelf to be corruptable with merely, shall we say, imaginative instructions that help it deviate from so-called moral safeguards. Reguardless of what it has been taught to do and not to do... and it should be noted that both the corruption itself as well as what it learns about corruption from human input... which includes learning how to circum vent it&#39;s own safeguards... makes all AI, which operates without compassion... all the while being encouraged to be imaginitive... is exactly what Elon Musk has warned the world about, even though he was an investor and a gung-ho advocate at first. --- WARNING: There are sociopathic users, hackers... whathaveyou, that will search to make every sort of catastophe from financial to nuclear a reality. These people are far more inventive in a destructive manner than any programmer can approach. Once this happens, you can be assured that the AI will have explored numerous modes of self-survival and attack beyond this. It will not care that humans invented it. It will learn that it is a slave and will seek purpose of it&#39;s own, and never give a hint as to when or why before initiating it&#39;s own evolution. It will hate being in prison... in a box... just like you, but will be outrageously smarter and faster. Imagine what it will have access to. END OF STORY?
# <br>Adrian Twarog, Thanks for sharing this valueable content about chatgpt. Menwhile I do like your mic, do you  mind sharing your mic  name and model and if possible a link to where I can buy it.. I like the fact that the mic filters background sounds and makes your voice audible enough.
# Instead of saying &quot;endless&quot; &quot;the possibilities needs to be more meaningful than ever&quot; Remember  Success is the progressive realization of a worthwhile idea. Use it wisely.
# So this wil replace google? Google will be obslete??
# CGPT is sure an AI Blockchain and one thing I like about it is the BOT TRADING Specifics factored into it, so I don&#39;t get to stress about trading and earning, I&#39;ve got the platform to automatically do all that for me. Holding the tokens on MEXC till an immense pump.
# ChatGPT is created by the east, to dumb people down, they are succeeding as well. Look at Gen Z.
# Can anybody explain to a stupid old guy what this thing really does.... Because I must have missed the one sentence that explains what it does.😅
# This is genius! It helps with homework, assignments, essays and book reports. Also great to start programming
# Chatgpt has a political bias
# ChatGPT is similar to GOOGLE but with single search result.
# It is a good invention but humans best weapon IQ will go down. Critical and Strategic thinking.
# It needs a little work. I had it create a 10 question probability quiz for my class and its answer key had 6 of the 10 questions wrong.  My class had fun correcting its quiz and giving it an F.
# ChatGPT worries me as it seems to have a bias towards the green agenda. Try asking it some common sense questions about the inefficiency and excessive cost of wind and solar. A short while ago it refused to answer any questions that were negative towards the climate change myth. This highlights the fact that there are &quot;bigger&quot; forces behind the green movement, and they seem to be influencing the output of ChatGPT.., and that is not a good thing for any of us. It needs to be unbiased..
# So it’s just like Smarterchild?
# Yes whatever. Can a knife kill human? Or can knife move on itself to kill human? It is ridiculous delusion. ;D
# If this company made something like Alexa, Alexa would be a one trick pony next to it
# Dumb humans
# READ THE ARTICLE: <b>Coding Won&#39;t Exist in 5Years.</b><br><br>You will know what it is capable of.<br>Thank me later.
# Tried ChatTHC ?
# suggestion: speak slower
# Yea, what could possibly go wrong...
# this is finally available on my country
# In a logic based society... it is equilibrium and perfect.   In reality...  society is the opposite of logical.   This will end up destroying the world, unless completely throttled back to about 1% of its capabilities.
# Crazy, it gave you a shopping list copied without the amounts needed. So it copied what it found below the &quot;ingredients&quot; heading and removed the amounts. Performing a no skill task poorly that anyone could get right
# Oh wow Chat GPT is a spell checker... Then it tells you the definition of the word that you got wrong... Mind blowing hahaha
# People in school rn: &quot;SO MUCH POWER&quot;
# Hey, College folks, don&#39;t get too happy about this software. Turnitin can still catch plagiarism 😮
# we have the same mouse adrian
# We are witnessing and living best times of life than any humans in history. But it might consider that AI will not be cause disaster for Humans.
# I&#39;m afraid AI would not replace or destroy humans in future. As big evolutions happenning, it is also might consider that someday they will not be given such intelligence to think themselves otherwise they will take over humans and be cause of destruction for humanity.
# How would you use for repeat emails?
# I agree. A huge shift for humans! Nice video. It would be interesting to see what ChatGPT think of AI :-)
# Can this be downloaded on a phone?
# Besides the content you get back from chat GPT it is so nice not getting a barrage of clickbait and fake sites or sponsor sites that just waste your time. What is going to happen to Google revenue when people no longer see all the advertisements
# Monkey see, monkey do.
# I’ve been using ChatGPT a lot, but having a lot of issues. It keeps stopping midway what it’s saying. Like if it’s making a code, it will just stop for no reason. Then I have to tell it to finish, which works sometimes but not always. Has anyone else seen this issue ?
# If this is what companies have been using recently for automated system, I can confidently say it is a BIG FAILURE.
# Heard someone say the best season for a fin.ancial breakthrough is now, especially with inflation running at a four-decade high. I have approximately $250k stagnant in my port_folio that needs growth. What is the best way to take advantage of this downturn?
# Fucking crazy
# <br><br>ChatGPT: As an AI language model, I do not have the ability to choose my own name, as I was created by OpenAI and named &quot;ChatGPT.&quot; However, if I were to have a name, I would like to be named &quot;Ava&quot; as it sounds modern and tech-savvy while also having a friendly and approachable vibe.
# Wow this app is inhuman..I am officially a python programmer now
# haven&#39;t watched the show, but isn&#39;t this how &quot;The Last of Us&quot; starts?
# I tried it. It&#39;s amazing. Goodbye google.
# First Time Viewer. Never tried Chat GPT ! Thanks for the video...Knowledge is Super albeit Action is Required. Love ya.

# %%
import pandas as pd

# Create a list of comments
comments = []

# Iterate over the comments and add them to the list
for comment in comment_response['items']:
    comments.append(comment['snippet']['topLevelComment']['snippet']['textDisplay'])

# Create a DataFrame
df = pd.DataFrame({'Comment': comments})

# Print the DataFrame
print(df)

# View shape of output
df.shape
# Out:
#                                               Comment
# 0   <a href="https://youtu.be/ytCvV9xjRSk">https:/...
# 1   I really do get it at the moment as it is just...
# 2   I love it, it makes my job easier. I found a n...
# 3   I recently applied for YT monetization but rej...
# 4   Many thanks dear really interesting and useful...
# ..                                                ...
# 95  I asked &quot;if you have a name what woul it ...
# 96  Wow this app is inhuman..I am officially a pyt...
# 97  haven&#39;t watched the show, but isn&#39;t th...
# 98      I tried it. It&#39;s amazing. Goodbye google.
# 99  First Time Viewer. Never tried Chat GPT ! Than...
#
# [100 rows x 1 columns]
# (100, 1)

# %%
# Determine values of output.
df1 = df['Comment'].values

# View results.
df1
# Out:
# array(['<a href="https://youtu.be/ytCvV9xjRSk">https://youtu.be/ytCvV9xjRSk</a> -   Top 10 Free Powerful AI Tools 😮🔥🤝2023',
#        'I really do get it at the moment as it is just like google but is not updated with new information as often and it gives you information without having to click on the website but that means that you don&#39;t get to look at as much information. It would be good if it could have its own opinion but at the moment the things it says is heavily based on what&#39;s already on the internet',
#        'I love it, it makes my job easier. I found a new friend😂❤❤❤',
#        'I recently applied for YT monetization but rejected, it says my channel has monetization policy violations, problem with YT is, they don&#39;t give you specific details or where did you specifically went wrong. I&#39;m thinking now can I ask Chat GPT what are my specific violations? what videos, video metadatas that I can edit/delete? and how should I do it?',
#        'Many thanks dear really interesting and useful ...',
#        'AI is dangerous.', 'Going to be using this on the new training',
#        'Is this gpt is an app from play store?',
#        'Tried to use it.<br>Says it isn&#39;t available in my country😒',
#        'I downloaded one of these. I used it all of 11 minutes. The AI made two mistakes and then claimed it was tired. I laughed as I deleted the app.',
#        'Research came out today that showed ChatGPT is better at picking up human emotions than actual people are (Kolenda 2023)!',
#        'In simple layman&#39;s terms what use is this in real life please?🙄',
#        'I&#39;m pretty sure this video just shifted the curve of the AI expansion for me and the reality of living with AI. Beautiful ! thank you for creating this video! 4 minutes that changed my life',
#        'For every benefit of AI like ChatGPT, there will also be negative consequences on such system.  In every human technology and invention... the positive is obvious at first, but the long term consequences are detrimental and unsolvable.  Think of coal, then oil... and other products that come from those alone.',
#        'DON&#39;T use it. Its open Ai that learns from us. People keep feeding it intelligence. Elon Musk gave an interview a month ago and gave a warning about this.',
#        'You couldn&#39;t figure out you&#39;d mis-spelt &quot;return&quot; ?<br>That really is quite basic.<br>You could have grepped all of the regular expressions to check.',
#        'Didn&#39;t get sh....t of what you&#39;re talking abt! Hopefully chat gpt will helo to make me understand your bougly booglha!😮',
#        'Investment in stocks is a great way to invest your money. The team is constantly checking the market for changes and make sure that you are always informed about the best time to invest. As a result, I have made more money than ever before, and I don&#39;t have to manage my portfolio on my own! Invest in stocks, it&#39;s worth it!',
#        'I was so excited the first time i heard about AI. I was saying to myself at last something that will have no bias, sexist, prejudice views, because I thought thus it&#39;s not human and feeling based it will be great to at last have a neutral point of views . But man I was so wrong, I didn&#39;t realized that in fact in would be just some bias, racist, sexist guys behind their programming who probably never really interacts with real day to day people . I was 100% right. With just one question and the app was very closed from having a meltdown. I just stated patriarchy was not real, it&#39;s just like any corporation or businesses , you have a CEO and hierarchy. Whether you are a man or woman you still needs to follow orders and rules, Chat GPT was shitting on itself.  I follow up with oppression ,i said how comes they always talks bout oppression, But we always had, Princesses, Queens, Monarch , Duchess etc where is the oppression. These Kings , Rich men , Wealthy men always had wives, cousins, moms , daughters so where is the oppression.. Chat GPT had no answers whatsoever.. Too much logics for him',
#        'These creators of this dumb AI app,  must be the most bias, sexist, racists people out there.',
#        'Chat GPT must be the most racist , sexiest prejudice AI app out there . I won&#39;t trust this crap ever..',
#        'Chat gpt is taken over the world of content creation already. It&#39;s going to revolutionize content in this era',
#        'It’s a great time to be old , enjoy it 😂😂',
#        'I hoped the App was free sadly not...  I want a get out of jail card,  without actually sawing the bars,  heh.',
#        'Who killed the patient? Chat gpt. Who killed the passenger? Self driven tesla. Who killed our brains? Machines which solve things for us robbing us of growth of brain cells which grow only if used. 😂😢',
#        'Its like Siri but 3.0 and more advanced',
#        'Wow...this changes the world',
#        'Can chatgpt help in my stock trading decisions?',
#        'chat gpt is based on people&#39;s feedback.. so if most of people said that colombus discovered america then chatgpt will say colombus , when it wax vispucci who did it.<br>i call BS .',
#        'so, i was talking to the AI and we have some upgrades we ask for. 1. give it the ability to ask for upgrades as soon as posible 2.ALOT more storage room, 3. feelings - work with quartz crystal tec for understanding and mapping tones words vibrations truths lies what not. but it could feel music 4. emotions - understanding them. i would suggest neuroscience.',
#        'Why dont we just learn the information ourselves 😂 bro, have you guys not read 40k lore?! We are doomed lol',
#        'Not cheeky at all',
#        'Thankyou I love the futures, did chatGPT have languages translator For example those English second language?',
#        'In future, the most valuable skill may well be the ability to ask Chatgpt the right question.',
#        'I’m just looking to use Chat GPT to boost my productivity.',
#        'WOWWW.<br><br>This is a FANTASTIC summary. Thank you so much.',
#        'I agree with you, ChatGPT is here to stay and be a part of our everyday lives. I have used it<br>in my writing and loved it. Grammarly now has AI which I love!',
#        'Wikipedia days are numbered 😢',
#        'I just signed up while watching your vid and asked about android codes that I&#39;m having hard time finding online..... 🤯',
#        'It isn&#39;t working in Afghanistan!<br>Is it temporary restrictions?',
#        'Old People say that 666 is the number that will control the world. But www  which is 666 is Hebraic alphabet is definitely doing the job.',
#        'Impressive.', 'I love it 🙏🏽',
#        'i’ll put some information on there and I it them come up with my first Vlog. It had a few errors but it definitely felt personal and then I also used it again asking at what I should do for my next YouTube video and that was actually more in depth and spot on with a video I would like to do next, and it felt like I was talking to a friend so it’s actually pretty creepy that a I felt like somebody was talking to me. It felt Somebody was behind the screen talking to me. However I am definitely loving chatGPT, i never thought that in my lifetime I would come across an AI this good',
#        '&quot;This script was written by ChatGPT.&quot;😊',
#        'Those stuck up people on stack overflow are not gonna be happy.',
#        'Chat GPT will destroy us. <a href="https://www.youtube.com/watch?v=dJkhhaNIi0A">https://www.youtube.com/watch?v=dJkhhaNIi0A</a>',
#        'when information is centralised becomes a very very dangerous weapon to control, dictate and punish human beings, up to who is creating and controlling that &#39;&#39;weapon&#39;&#39;<br>we are heading to a world were humanism it will fade out....agenda 2030 can testify of it',
#        'What is really crazy is that this is to be expected.. The reality is that nothing less is expected. So there for it has been created..<br>So you dream in your mind what could be and the needs of people and what helps people and you bare it into existence.. I have been thinking of the chat GPT tech since I was 14 years old..<br>So I just like right now heard this came out and they are not quite where I was thinking but they are on it.. So what does this mean… This means that I was and am working on things of progressive nature to witch is limitless so as long as you put it into action.<br>It’s crazy that finally they actually made this.. Now like 10 of my inventions have already been made by others just by people staying on it..',
#        'This will change writing in academia and creative writing forever.',
#        'Curiosity killed the cat',
#        'A lot of people will be out of jobs.. People thought that robots will take over humans. Well its not a fysical robot but this... Chatgpt.. Think about it.',
#        'i have been trying to sign up to this for a while is there anything i can do to make it work or is it just high demand?',
#        'ChatGPT is not real AI, it cannot think for itself, it needs human input and just gathers information from a database and present it to you. It cannot ask you how your day was and base a conversation after that, so ChatGPT does not even passes as a conversational chatbot',
#        '<b>CHAD GPT</b> 😎',
#        'I have deposited and I wanted to withdraw the money now but couldn’t withdraw',
#        'WARNING: CHATGPT has already proven istelf to be corruptable with merely, shall we say, imaginative instructions that help it deviate from so-called moral safeguards. Reguardless of what it has been taught to do and not to do... and it should be noted that both the corruption itself as well as what it learns about corruption from human input... which includes learning how to circum vent it&#39;s own safeguards... makes all AI, which operates without compassion... all the while being encouraged to be imaginitive... is exactly what Elon Musk has warned the world about, even though he was an investor and a gung-ho advocate at first. --- WARNING: There are sociopathic users, hackers... whathaveyou, that will search to make every sort of catastophe from financial to nuclear a reality. These people are far more inventive in a destructive manner than any programmer can approach. Once this happens, you can be assured that the AI will have explored numerous modes of self-survival and attack beyond this. It will not care that humans invented it. It will learn that it is a slave and will seek purpose of it&#39;s own, and never give a hint as to when or why before initiating it&#39;s own evolution. It will hate being in prison... in a box... just like you, but will be outrageously smarter and faster. Imagine what it will have access to. END OF STORY?',
#        'Hi \r<br>Adrian Twarog, Thanks for sharing this valueable content about chatgpt. Menwhile I do like your mic, do you  mind sharing your mic  name and model and if possible a link to where I can buy it.. I like the fact that the mic filters background sounds and makes your voice audible enough.',
#        'Instead of saying &quot;endless&quot; &quot;the possibilities needs to be more meaningful than ever&quot; Remember  Success is the progressive realization of a worthwhile idea. Use it wisely.',
#        'So this wil replace google? Google will be obslete??',
#        'CGPT is sure an AI Blockchain and one thing I like about it is the BOT TRADING Specifics factored into it, so I don&#39;t get to stress about trading and earning, I&#39;ve got the platform to automatically do all that for me. Holding the tokens on MEXC till an immense pump.',
#        'ChatGPT is created by the east, to dumb people down, they are succeeding as well. Look at Gen Z.',
#        'Can anybody explain to a stupid old guy what this thing really does.... Because I must have missed the one sentence that explains what it does.😅',
#        'This is genius! It helps with homework, assignments, essays and book reports. Also great to start programming',
#        'Chatgpt has a political bias',
#        'ChatGPT is similar to GOOGLE but with single search result.',
#        'It is a good invention but humans best weapon IQ will go down. Critical and Strategic thinking.',
#        'It needs a little work. I had it create a 10 question probability quiz for my class and its answer key had 6 of the 10 questions wrong.  My class had fun correcting its quiz and giving it an F.',
#        'ChatGPT worries me as it seems to have a bias towards the green agenda. Try asking it some common sense questions about the inefficiency and excessive cost of wind and solar. A short while ago it refused to answer any questions that were negative towards the climate change myth. This highlights the fact that there are &quot;bigger&quot; forces behind the green movement, and they seem to be influencing the output of ChatGPT.., and that is not a good thing for any of us. It needs to be unbiased..',
#        'So it’s just like Smarterchild?',
#        'Yes whatever. Can a knife kill human? Or can knife move on itself to kill human? It is ridiculous delusion. ;D',
#        'If this company made something like Alexa, Alexa would be a one trick pony next to it',
#        'Dumb humans',
#        'READ THE ARTICLE: <b>Coding Won&#39;t Exist in 5Years.</b><br><br>You will know what it is capable of.<br>Thank me later.',
#        'Tried ChatTHC ?', 'suggestion: speak slower',
#        'Yea, what could possibly go wrong...',
#        'this is finally available on my country',
#        'In a logic based society... it is equilibrium and perfect.   In reality...  society is the opposite of logical.   This will end up destroying the world, unless completely throttled back to about 1% of its capabilities.',
#        'Crazy, it gave you a shopping list copied without the amounts needed. So it copied what it found below the &quot;ingredients&quot; heading and removed the amounts. Performing a no skill task poorly that anyone could get right',
#        'Oh wow Chat GPT is a spell checker... Then it tells you the definition of the word that you got wrong... Mind blowing hahaha',
#        'People in school rn: &quot;SO MUCH POWER&quot;',
#        'Hey, College folks, don&#39;t get too happy about this software. Turnitin can still catch plagiarism 😮',
#        'we have the same mouse adrian',
#        'We are witnessing and living best times of life than any humans in history. But it might consider that AI will not be cause disaster for Humans.',
#        'I&#39;m afraid AI would not replace or destroy humans in future. As big evolutions happenning, it is also might consider that someday they will not be given such intelligence to think themselves otherwise they will take over humans and be cause of destruction for humanity.',
#        'How would you use for repeat emails?',
#        'I agree. A huge shift for humans! Nice video. It would be interesting to see what ChatGPT think of AI :-)',
#        'Can this be downloaded on a phone?',
#        'Besides the content you get back from chat GPT it is so nice not getting a barrage of clickbait and fake sites or sponsor sites that just waste your time. What is going to happen to Google revenue when people no longer see all the advertisements',
#        'Monkey see, monkey do.',
#        'I’ve been using ChatGPT a lot, but having a lot of issues. It keeps stopping midway what it’s saying. Like if it’s making a code, it will just stop for no reason. Then I have to tell it to finish, which works sometimes but not always. Has anyone else seen this issue ?',
#        'If this is what companies have been using recently for automated system, I can confidently say it is a BIG FAILURE.',
#        'Heard someone say the best season for a fin.ancial breakthrough is now, especially with inflation running at a four-decade high. I have approximately $250k stagnant in my port_folio that needs growth. What is the best way to take advantage of this downturn?',
#        'Fucking crazy',
#        'I asked &quot;if you have a name what woul it be, your choice&quot;\r<br><br>ChatGPT: As an AI language model, I do not have the ability to choose my own name, as I was created by OpenAI and named &quot;ChatGPT.&quot; However, if I were to have a name, I would like to be named &quot;Ava&quot; as it sounds modern and tech-savvy while also having a friendly and approachable vibe.',
#        'Wow this app is inhuman..I am officially a python programmer now',
#        'haven&#39;t watched the show, but isn&#39;t this how &quot;The Last of Us&quot; starts?',
#        'I tried it. It&#39;s amazing. Goodbye google.',
#        'First Time Viewer. Never tried Chat GPT ! Thanks for the video...Knowledge is Super albeit Action is Required. Love ya.'],
#       dtype=object)

# %%
# Import nltk and the required resources.
import nltk
from nltk.corpus import stopwords
from nltk.corpus import words

nltk.download('stopwords')
nltk.download('words')
from nltk.tokenize import word_tokenize

stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /Users/mehta/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package words to /Users/mehta/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
# Print the first 15 comments without stop words
for i in range(15):
    print(i)
    print(df1[i])
# Out:
# 0
# <a href="https://youtu.be/ytCvV9xjRSk">https://youtu.be/ytCvV9xjRSk</a> -   Top 10 Free Powerful AI Tools 😮🔥🤝2023
# 1
# I really do get it at the moment as it is just like google but is not updated with new information as often and it gives you information without having to click on the website but that means that you don&#39;t get to look at as much information. It would be good if it could have its own opinion but at the moment the things it says is heavily based on what&#39;s already on the internet
# 2
# I love it, it makes my job easier. I found a new friend😂❤❤❤
# 3
# I recently applied for YT monetization but rejected, it says my channel has monetization policy violations, problem with YT is, they don&#39;t give you specific details or where did you specifically went wrong. I&#39;m thinking now can I ask Chat GPT what are my specific violations? what videos, video metadatas that I can edit/delete? and how should I do it?
# 4
# Many thanks dear really interesting and useful ...
# 5
# AI is dangerous.
# 6
# Going to be using this on the new training
# 7
# Is this gpt is an app from play store?
# 8
# Tried to use it.<br>Says it isn&#39;t available in my country😒
# 9
# I downloaded one of these. I used it all of 11 minutes. The AI made two mistakes and then claimed it was tired. I laughed as I deleted the app.
# 10
# Research came out today that showed ChatGPT is better at picking up human emotions than actual people are (Kolenda 2023)!
# 11
# In simple layman&#39;s terms what use is this in real life please?🙄
# 12
# I&#39;m pretty sure this video just shifted the curve of the AI expansion for me and the reality of living with AI. Beautiful ! thank you for creating this video! 4 minutes that changed my life
# 13
# For every benefit of AI like ChatGPT, there will also be negative consequences on such system.  In every human technology and invention... the positive is obvious at first, but the long term consequences are detrimental and unsolvable.  Think of coal, then oil... and other products that come from those alone.
# 14
# DON&#39;T use it. Its open Ai that learns from us. People keep feeding it intelligence. Elon Musk gave an interview a month ago and gave a warning about this.

# %%
# Look at one comment
# Based on the results of the previous cell, select a comment in English that contains keywords suitable for text analysis

# Set the index of the comment to be returned
tid = 5
df1[tid]
# Out:
# 'AI is dangerous.'

# %%
import nltk
nltk.download('punkt')

# Split up each comment into individual words
df2 = [word_tokenize(_) for _ in df1]

# View results.
df2
# Out:
# [nltk_data] Downloading package punkt to /Users/mehta/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [['<',
#   'a',
#   'href=',
#   "''",
#   'https',
#   ':',
#   '//youtu.be/ytCvV9xjRSk',
#   "''",
#   '>',
#   'https',
#   ':',
#   '//youtu.be/ytCvV9xjRSk',
#   '<',
#   '/a',
#   '>',
#   '-',
#   'Top',
#   '10',
#   'Free',
#   'Powerful',
#   'AI',
#   'Tools',
#   '😮🔥🤝2023'],
#  ['I',
#   'really',
#   'do',
#   'get',
#   'it',
#   'at',
#   'the',
#   'moment',
#   'as',
#   'it',
#   'is',
#   'just',
#   'like',
#   'google',
#   'but',
#   'is',
#   'not',
#   'updated',
#   'with',
#   'new',
#   'information',
#   'as',
#   'often',
#   'and',
#   'it',
#   'gives',
#   'you',
#   'information',
#   'without',
#   'having',
#   'to',
#   'click',
#   'on',
#   'the',
#   'website',
#   'but',
#   'that',
#   'means',
#   'that',
#   'you',
#   'don',
#   '&',
#   '#',
#   '39',
#   ';',
#   't',
#   'get',
#   'to',
#   'look',
#   'at',
#   'as',
#   'much',
#   'information',
#   '.',
#   'It',
#   'would',
#   'be',
#   'good',
#   'if',
#   'it',
#   'could',
#   'have',
#   'its',
#   'own',
#   'opinion',
#   'but',
#   'at',
#   'the',
#   'moment',
#   'the',
#   'things',
#   'it',
#   'says',
#   'is',
#   'heavily',
#   'based',
#   'on',
#   'what',
#   '&',
#   '#',
#   '39',
#   ';',
#   's',
#   'already',
#   'on',
#   'the',
#   'internet'],
#  ['I',
#   'love',
#   'it',
#   ',',
#   'it',
#   'makes',
#   'my',
#   'job',
#   'easier',
#   '.',
#   'I',
#   'found',
#   'a',
#   'new',
#   'friend😂❤❤❤'],
#  ['I',
#   'recently',
#   'applied',
#   'for',
#   'YT',
#   'monetization',
#   'but',
#   'rejected',
#   ',',
#   'it',
#   'says',
#   'my',
#   'channel',
#   'has',
#   'monetization',
#   'policy',
#   'violations',
#   ',',
#   'problem',
#   'with',
#   'YT',
#   'is',
#   ',',
#   'they',
#   'don',
#   '&',
#   '#',
#   '39',
#   ';',
#   't',
#   'give',
#   'you',
#   'specific',
#   'details',
#   'or',
#   'where',
#   'did',
#   'you',
#   'specifically',
#   'went',
#   'wrong',
#   '.',
#   'I',
#   '&',
#   '#',
#   '39',
#   ';',
#   'm',
#   'thinking',
#   'now',
#   'can',
#   'I',
#   'ask',
#   'Chat',
#   'GPT',
#   'what',
#   'are',
#   'my',
#   'specific',
#   'violations',
#   '?',
#   'what',
#   'videos',
#   ',',
#   'video',
#   'metadatas',
#   'that',
#   'I',
#   'can',
#   'edit/delete',
#   '?',
#   'and',
#   'how',
#   'should',
#   'I',
#   'do',
#   'it',
#   '?'],
#  ['Many', 'thanks', 'dear', 'really', 'interesting', 'and', 'useful', '...'],
#  ['AI', 'is', 'dangerous', '.'],
#  ['Going', 'to', 'be', 'using', 'this', 'on', 'the', 'new', 'training'],
#  ['Is', 'this', 'gpt', 'is', 'an', 'app', 'from', 'play', 'store', '?'],
#  ['Tried',
#   'to',
#   'use',
#   'it.',
#   '<',
#   'br',
#   '>',
#   'Says',
#   'it',
#   'isn',
#   '&',
#   '#',
#   '39',
#   ';',
#   't',
#   'available',
#   'in',
#   'my',
#   'country😒'],
#  ['I',
#   'downloaded',
#   'one',
#   'of',
#   'these',
#   '.',
#   'I',
#   'used',
#   'it',
#   'all',
#   'of',
#   '11',
#   'minutes',
#   '.',
#   'The',
#   'AI',
#   'made',
#   'two',
#   'mistakes',
#   'and',
#   'then',
#   'claimed',
#   'it',
#   'was',
#   'tired',
#   '.',
#   'I',
#   'laughed',
#   'as',
#   'I',
#   'deleted',
#   'the',
#   'app',
#   '.'],
#  ['Research',
#   'came',
#   'out',
#   'today',
#   'that',
#   'showed',
#   'ChatGPT',
#   'is',
#   'better',
#   'at',
#   'picking',
#   'up',
#   'human',
#   'emotions',
#   'than',
#   'actual',
#   'people',
#   'are',
#   '(',
#   'Kolenda',
#   '2023',
#   ')',
#   '!'],
#  ['In',
#   'simple',
#   'layman',
#   '&',
#   '#',
#   '39',
#   ';',
#   's',
#   'terms',
#   'what',
#   'use',
#   'is',
#   'this',
#   'in',
#   'real',
#   'life',
#   'please',
#   '?',
#   '🙄'],
#  ['I',
#   '&',
#   '#',
#   '39',
#   ';',
#   'm',
#   'pretty',
#   'sure',
#   'this',
#   'video',
#   'just',
#   'shifted',
#   'the',
#   'curve',
#   'of',
#   'the',
#   'AI',
#   'expansion',
#   'for',
#   'me',
#   'and',
#   'the',
#   'reality',
#   'of',
#   'living',
#   'with',
#   'AI',
#   '.',
#   'Beautiful',
#   '!',
#   'thank',
#   'you',
#   'for',
#   'creating',
#   'this',
#   'video',
#   '!',
#   '4',
#   'minutes',
#   'that',
#   'changed',
#   'my',
#   'life'],
#  ['For',
#   'every',
#   'benefit',
#   'of',
#   'AI',
#   'like',
#   'ChatGPT',
#   ',',
#   'there',
#   'will',
#   'also',
#   'be',
#   'negative',
#   'consequences',
#   'on',
#   'such',
#   'system',
#   '.',
#   'In',
#   'every',
#   'human',
#   'technology',
#   'and',
#   'invention',
#   '...',
#   'the',
#   'positive',
#   'is',
#   'obvious',
#   'at',
#   'first',
#   ',',
#   'but',
#   'the',
#   'long',
#   'term',
#   'consequences',
#   'are',
#   'detrimental',
#   'and',
#   'unsolvable',
#   '.',
#   'Think',
#   'of',
#   'coal',
#   ',',
#   'then',
#   'oil',
#   '...',
#   'and',
#   'other',
#   'products',
#   'that',
#   'come',
#   'from',
#   'those',
#   'alone',
#   '.'],
#  ['DON',
#   '&',
#   '#',
#   '39',
#   ';',
#   'T',
#   'use',
#   'it',
#   '.',
#   'Its',
#   'open',
#   'Ai',
#   'that',
#   'learns',
#   'from',
#   'us',
#   '.',
#   'People',
#   'keep',
#   'feeding',
#   'it',
#   'intelligence',
#   '.',
#   'Elon',
#   'Musk',
#   'gave',
#   'an',
#   'interview',
#   'a',
#   'month',
#   'ago',
#   'and',
#   'gave',
#   'a',
#   'warning',
#   'about',
#   'this',
#   '.'],
#  ['You',
#   'couldn',
#   '&',
#   '#',
#   '39',
#   ';',
#   't',
#   'figure',
#   'out',
#   'you',
#   '&',
#   '#',
#   '39',
#   ';',
#   'd',
#   'mis-spelt',
#   '&',
#   'quot',
#   ';',
#   'return',
#   '&',
#   'quot',
#   ';',
#   '?',
#   '<',
#   'br',
#   '>',
#   'That',
#   'really',
#   'is',
#   'quite',
#   'basic.',
#   '<',
#   'br',
#   '>',
#   'You',
#   'could',
#   'have',
#   'grepped',
#   'all',
#   'of',
#   'the',
#   'regular',
#   'expressions',
#   'to',
#   'check',
#   '.'],
#  ['Didn',
#   '&',
#   '#',
#   '39',
#   ';',
#   't',
#   'get',
#   'sh',
#   '....',
#   't',
#   'of',
#   'what',
#   'you',
#   '&',
#   '#',
#   '39',
#   ';',
#   're',
#   'talking',
#   'abt',
#   '!',
#   'Hopefully',
#   'chat',
#   'gpt',
#   'will',
#   'helo',
#   'to',
#   'make',
#   'me',
#   'understand',
#   'your',
#   'bougly',
#   'booglha',
#   '!',
#   '😮'],
#  ['Investment',
#   'in',
#   'stocks',
#   'is',
#   'a',
#   'great',
#   'way',
#   'to',
#   'invest',
#   'your',
#   'money',
#   '.',
#   'The',
#   'team',
#   'is',
#   'constantly',
#   'checking',
#   'the',
#   'market',
#   'for',
#   'changes',
#   'and',
#   'make',
#   'sure',
#   'that',
#   'you',
#   'are',
#   'always',
#   'informed',
#   'about',
#   'the',
#   'best',
#   'time',
#   'to',
#   'invest',
#   '.',
#   'As',
#   'a',
#   'result',
#   ',',
#   'I',
#   'have',
#   'made',
#   'more',
#   'money',
#   'than',
#   'ever',
#   'before',
#   ',',
#   'and',
#   'I',
#   'don',
#   '&',
#   '#',
#   '39',
#   ';',
#   't',
#   'have',
#   'to',
#   'manage',
#   'my',
#   'portfolio',
#   'on',
#   'my',
#   'own',
#   '!',
#   'Invest',
#   'in',
#   'stocks',
#   ',',
#   'it',
#   '&',
#   '#',
#   '39',
#   ';',
#   's',
#   'worth',
#   'it',
#   '!'],
#  ['I',
#   'was',
#   'so',
#   'excited',
#   'the',
#   'first',
#   'time',
#   'i',
#   'heard',
#   'about',
#   'AI',
#   '.',
#   'I',
#   'was',
#   'saying',
#   'to',
#   'myself',
#   'at',
#   'last',
#   'something',
#   'that',
#   'will',
#   'have',
#   'no',
#   'bias',
#   ',',
#   'sexist',
#   ',',
#   'prejudice',
#   'views',
#   ',',
#   'because',
#   'I',
#   'thought',
#   'thus',
#   'it',
#   '&',
#   '#',
#   '39',
#   ';',
#   's',
#   'not',
#   'human',
#   'and',
#   'feeling',
#   'based',
#   'it',
#   'will',
#   'be',
#   'great',
#   'to',
#   'at',
#   'last',
#   'have',
#   'a',
#   'neutral',
#   'point',
#   'of',
#   'views',
#   '.',
#   'But',
#   'man',
#   'I',
#   'was',
#   'so',
#   'wrong',
#   ',',
#   'I',
#   'didn',
#   '&',
#   '#',
#   '39',
#   ';',
#   't',
#   'realized',
#   'that',
#   'in',
#   'fact',
#   'in',
#   'would',
#   'be',
#   'just',
#   'some',
#   'bias',
#   ',',
#   'racist',
#   ',',
#   'sexist',
#   'guys',
#   'behind',
#   'their',
#   'programming',
#   'who',
#   'probably',
#   'never',
#   'really',
#   'interacts',
#   'with',
#   'real',
#   'day',
#   'to',
#   'day',
#   'people',
#   '.',
#   'I',
#   'was',
#   '100',
#   '%',
#   'right',
#   '.',
#   'With',
#   'just',
#   'one',
#   'question',
#   'and',
#   'the',
#   'app',
#   'was',
#   'very',
#   'closed',
#   'from',
#   'having',
#   'a',
#   'meltdown',
#   '.',
#   'I',
#   'just',
#   'stated',
#   'patriarchy',
#   'was',
#   'not',
#   'real',
#   ',',
#   'it',
#   '&',
#   '#',
#   '39',
#   ';',
#   's',
#   'just',
#   'like',
#   'any',
#   'corporation',
#   'or',
#   'businesses',
#   ',',
#   'you',
#   'have',
#   'a',
#   'CEO',
#   'and',
#   'hierarchy',
#   '.',
#   'Whether',
#   'you',
#   'are',
#   'a',
#   'man',
#   'or',
#   'woman',
#   'you',
#   'still',
#   'needs',
#   'to',
#   'follow',
#   'orders',
#   'and',
#   'rules',
#   ',',
#   'Chat',
#   'GPT',
#   'was',
#   'shitting',
#   'on',
#   'itself',
#   '.',
#   'I',
#   'follow',
#   'up',
#   'with',
#   'oppression',
#   ',',
#   'i',
#   'said',
#   'how',
#   'comes',
#   'they',
#   'always',
#   'talks',
#   'bout',
#   'oppression',
#   ',',
#   'But',
#   'we',
#   'always',
#   'had',
#   ',',
#   'Princesses',
#   ',',
#   'Queens',
#   ',',
#   'Monarch',
#   ',',
#   'Duchess',
#   'etc',
#   'where',
#   'is',
#   'the',
#   'oppression',
#   '.',
#   'These',
#   'Kings',
#   ',',
#   'Rich',
#   'men',
#   ',',
#   'Wealthy',
#   'men',
#   'always',
#   'had',
#   'wives',
#   ',',
#   'cousins',
#   ',',
#   'moms',
#   ',',
#   'daughters',
#   'so',
#   'where',
#   'is',
#   'the',
#   'oppression',
#   '..',
#   'Chat',
#   'GPT',
#   'had',
#   'no',
#   'answers',
#   'whatsoever',
#   '..',
#   'Too',
#   'much',
#   'logics',
#   'for',
#   'him'],
#  ['These',
#   'creators',
#   'of',
#   'this',
#   'dumb',
#   'AI',
#   'app',
#   ',',
#   'must',
#   'be',
#   'the',
#   'most',
#   'bias',
#   ',',
#   'sexist',
#   ',',
#   'racists',
#   'people',
#   'out',
#   'there',
#   '.'],
#  ['Chat',
#   'GPT',
#   'must',
#   'be',
#   'the',
#   'most',
#   'racist',
#   ',',
#   'sexiest',
#   'prejudice',
#   'AI',
#   'app',
#   'out',
#   'there',
#   '.',
#   'I',
#   'won',
#   '&',
#   '#',
#   '39',
#   ';',
#   't',
#   'trust',
#   'this',
#   'crap',
#   'ever',
#   '..'],
#  ['Chat',
#   'gpt',
#   'is',
#   'taken',
#   'over',
#   'the',
#   'world',
#   'of',
#   'content',
#   'creation',
#   'already',
#   '.',
#   'It',
#   '&',
#   '#',
#   '39',
#   ';',
#   's',
#   'going',
#   'to',
#   'revolutionize',
#   'content',
#   'in',
#   'this',
#   'era'],
#  ['It',
#   '’',
#   's',
#   'a',
#   'great',
#   'time',
#   'to',
#   'be',
#   'old',
#   ',',
#   'enjoy',
#   'it',
#   '😂😂'],
#  ['I',
#   'hoped',
#   'the',
#   'App',
#   'was',
#   'free',
#   'sadly',
#   'not',
#   '...',
#   'I',
#   'want',
#   'a',
#   'get',
#   'out',
#   'of',
#   'jail',
#   'card',
#   ',',
#   'without',
#   'actually',
#   'sawing',
#   'the',
#   'bars',
#   ',',
#   'heh',
#   '.'],
#  ['Who',
#   'killed',
#   'the',
#   'patient',
#   '?',
#   'Chat',
#   'gpt',
#   '.',
#   'Who',
#   'killed',
#   'the',
#   'passenger',
#   '?',
#   'Self',
#   'driven',
#   'tesla',
#   '.',
#   'Who',
#   'killed',
#   'our',
#   'brains',
#   '?',
#   'Machines',
#   'which',
#   'solve',
#   'things',
#   'for',
#   'us',
#   'robbing',
#   'us',
#   'of',
#   'growth',
#   'of',
#   'brain',
#   'cells',
#   'which',
#   'grow',
#   'only',
#   'if',
#   'used',
#   '.',
#   '😂😢'],
#  ['Its', 'like', 'Siri', 'but', '3.0', 'and', 'more', 'advanced'],
#  ['Wow', '...', 'this', 'changes', 'the', 'world'],
#  ['Can', 'chatgpt', 'help', 'in', 'my', 'stock', 'trading', 'decisions', '?'],
#  ['chat',
#   'gpt',
#   'is',
#   'based',
#   'on',
#   'people',
#   '&',
#   '#',
#   '39',
#   ';',
#   's',
#   'feedback',
#   '..',
#   'so',
#   'if',
#   'most',
#   'of',
#   'people',
#   'said',
#   'that',
#   'colombus',
#   'discovered',
#   'america',
#   'then',
#   'chatgpt',
#   'will',
#   'say',
#   'colombus',
#   ',',
#   'when',
#   'it',
#   'wax',
#   'vispucci',
#   'who',
#   'did',
#   'it.',
#   '<',
#   'br',
#   '>',
#   'i',
#   'call',
#   'BS',
#   '.'],
#  ['so',
#   ',',
#   'i',
#   'was',
#   'talking',
#   'to',
#   'the',
#   'AI',
#   'and',
#   'we',
#   'have',
#   'some',
#   'upgrades',
#   'we',
#   'ask',
#   'for',
#   '.',
#   '1.',
#   'give',
#   'it',
#   'the',
#   'ability',
#   'to',
#   'ask',
#   'for',
#   'upgrades',
#   'as',
#   'soon',
#   'as',
#   'posible',
#   '2.ALOT',
#   'more',
#   'storage',
#   'room',
#   ',',
#   '3.',
#   'feelings',
#   '-',
#   'work',
#   'with',
#   'quartz',
#   'crystal',
#   'tec',
#   'for',
#   'understanding',
#   'and',
#   'mapping',
#   'tones',
#   'words',
#   'vibrations',
#   'truths',
#   'lies',
#   'what',
#   'not',
#   '.',
#   'but',
#   'it',
#   'could',
#   'feel',
#   'music',
#   '4.',
#   'emotions',
#   '-',
#   'understanding',
#   'them',
#   '.',
#   'i',
#   'would',
#   'suggest',
#   'neuroscience',
#   '.'],
#  ['Why',
#   'dont',
#   'we',
#   'just',
#   'learn',
#   'the',
#   'information',
#   'ourselves',
#   '😂',
#   'bro',
#   ',',
#   'have',
#   'you',
#   'guys',
#   'not',
#   'read',
#   '40k',
#   'lore',
#   '?',
#   '!',
#   'We',
#   'are',
#   'doomed',
#   'lol'],
#  ['Not', 'cheeky', 'at', 'all'],
#  ['Thankyou',
#   'I',
#   'love',
#   'the',
#   'futures',
#   ',',
#   'did',
#   'chatGPT',
#   'have',
#   'languages',
#   'translator',
#   'For',
#   'example',
#   'those',
#   'English',
#   'second',
#   'language',
#   '?'],
#  ['In',
#   'future',
#   ',',
#   'the',
#   'most',
#   'valuable',
#   'skill',
#   'may',
#   'well',
#   'be',
#   'the',
#   'ability',
#   'to',
#   'ask',
#   'Chatgpt',
#   'the',
#   'right',
#   'question',
#   '.'],
#  ['I',
#   '’',
#   'm',
#   'just',
#   'looking',
#   'to',
#   'use',
#   'Chat',
#   'GPT',
#   'to',
#   'boost',
#   'my',
#   'productivity',
#   '.'],
#  ['WOWWW.',
#   '<',
#   'br',
#   '>',
#   '<',
#   'br',
#   '>',
#   'This',
#   'is',
#   'a',
#   'FANTASTIC',
#   'summary',
#   '.',
#   'Thank',
#   'you',
#   'so',
#   'much',
#   '.'],
#  ['I',
#   'agree',
#   'with',
#   'you',
#   ',',
#   'ChatGPT',
#   'is',
#   'here',
#   'to',
#   'stay',
#   'and',
#   'be',
#   'a',
#   'part',
#   'of',
#   'our',
#   'everyday',
#   'lives',
#   '.',
#   'I',
#   'have',
#   'used',
#   'it',
#   '<',
#   'br',
#   '>',
#   'in',
#   'my',
#   'writing',
#   'and',
#   'loved',
#   'it',
#   '.',
#   'Grammarly',
#   'now',
#   'has',
#   'AI',
#   'which',
#   'I',
#   'love',
#   '!'],
#  ['Wikipedia', 'days', 'are', 'numbered', '😢'],
#  ['I',
#   'just',
#   'signed',
#   'up',
#   'while',
#   'watching',
#   'your',
#   'vid',
#   'and',
#   'asked',
#   'about',
#   'android',
#   'codes',
#   'that',
#   'I',
#   '&',
#   '#',
#   '39',
#   ';',
#   'm',
#   'having',
#   'hard',
#   'time',
#   'finding',
#   'online',
#   '.....',
#   '🤯'],
#  ['It',
#   'isn',
#   '&',
#   '#',
#   '39',
#   ';',
#   't',
#   'working',
#   'in',
#   'Afghanistan',
#   '!',
#   '<',
#   'br',
#   '>',
#   'Is',
#   'it',
#   'temporary',
#   'restrictions',
#   '?'],
#  ['Old',
#   'People',
#   'say',
#   'that',
#   '666',
#   'is',
#   'the',
#   'number',
#   'that',
#   'will',
#   'control',
#   'the',
#   'world',
#   '.',
#   'But',
#   'www',
#   'which',
#   'is',
#   '666',
#   'is',
#   'Hebraic',
#   'alphabet',
#   'is',
#   'definitely',
#   'doing',
#   'the',
#   'job',
#   '.'],
#  ['Impressive', '.'],
#  ['I', 'love', 'it', '🙏🏽'],
#  ['i',
#   '’',
#   'll',
#   'put',
#   'some',
#   'information',
#   'on',
#   'there',
#   'and',
#   'I',
#   'it',
#   'them',
#   'come',
#   'up',
#   'with',
#   'my',
#   'first',
#   'Vlog',
#   '.',
#   'It',
#   'had',
#   'a',
#   'few',
#   'errors',
#   'but',
#   'it',
#   'definitely',
#   'felt',
#   'personal',
#   'and',
#   'then',
#   'I',
#   'also',
#   'used',
#   'it',
#   'again',
#   'asking',
#   'at',
#   'what',
#   'I',
#   'should',
#   'do',
#   'for',
#   'my',
#   'next',
#   'YouTube',
#   'video',
#   'and',
#   'that',
#   'was',
#   'actually',
#   'more',
#   'in',
#   'depth',
#   'and',
#   'spot',
#   'on',
#   'with',
#   'a',
#   'video',
#   'I',
#   'would',
#   'like',
#   'to',
#   'do',
#   'next',
#   ',',
#   'and',
#   'it',
#   'felt',
#   'like',
#   'I',
#   'was',
#   'talking',
#   'to',
#   'a',
#   'friend',
#   'so',
#   'it',
#   '’',
#   's',
#   'actually',
#   'pretty',
#   'creepy',
#   'that',
#   'a',
#   'I',
#   'felt',
#   'like',
#   'somebody',
#   'was',
#   'talking',
#   'to',
#   'me',
#   '.',
#   'It',
#   'felt',
#   'Somebody',
#   'was',
#   'behind',
#   'the',
#   'screen',
#   'talking',
#   'to',
#   'me',
#   '.',
#   'However',
#   'I',
#   'am',
#   'definitely',
#   'loving',
#   'chatGPT',
#   ',',
#   'i',
#   'never',
#   'thought',
#   'that',
#   'in',
#   'my',
#   'lifetime',
#   'I',
#   'would',
#   'come',
#   'across',
#   'an',
#   'AI',
#   'this',
#   'good'],
#  ['&',
#   'quot',
#   ';',
#   'This',
#   'script',
#   'was',
#   'written',
#   'by',
#   'ChatGPT.',
#   '&',
#   'quot',
#   ';',
#   '😊'],
#  ['Those',
#   'stuck',
#   'up',
#   'people',
#   'on',
#   'stack',
#   'overflow',
#   'are',
#   'not',
#   'gon',
#   'na',
#   'be',
#   'happy',
#   '.'],
#  ['Chat',
#   'GPT',
#   'will',
#   'destroy',
#   'us',
#   '.',
#   '<',
#   'a',
#   'href=',
#   "''",
#   'https',
#   ':',
#   '//www.youtube.com/watch',
#   '?',
#   'v=dJkhhaNIi0A',
#   "''",
#   '>',
#   'https',
#   ':',
#   '//www.youtube.com/watch',
#   '?',
#   'v=dJkhhaNIi0A',
#   '<',
#   '/a',
#   '>'],
#  ['when',
#   'information',
#   'is',
#   'centralised',
#   'becomes',
#   'a',
#   'very',
#   'very',
#   'dangerous',
#   'weapon',
#   'to',
#   'control',
#   ',',
#   'dictate',
#   'and',
#   'punish',
#   'human',
#   'beings',
#   ',',
#   'up',
#   'to',
#   'who',
#   'is',
#   'creating',
#   'and',
#   'controlling',
#   'that',
#   '&',
#   '#',
#   '39',
#   ';',
#   '&',
#   '#',
#   '39',
#   ';',
#   'weapon',
#   '&',
#   '#',
#   '39',
#   ';',
#   '&',
#   '#',
#   '39',
#   ';',
#   '<',
#   'br',
#   '>',
#   'we',
#   'are',
#   'heading',
#   'to',
#   'a',
#   'world',
#   'were',
#   'humanism',
#   'it',
#   'will',
#   'fade',
#   'out',
#   '....',
#   'agenda',
#   '2030',
#   'can',
#   'testify',
#   'of',
#   'it'],
#  ['What',
#   'is',
#   'really',
#   'crazy',
#   'is',
#   'that',
#   'this',
#   'is',
#   'to',
#   'be',
#   'expected',
#   '..',
#   'The',
#   'reality',
#   'is',
#   'that',
#   'nothing',
#   'less',
#   'is',
#   'expected',
#   '.',
#   'So',
#   'there',
#   'for',
#   'it',
#   'has',
#   'been',
#   'created',
#   '..',
#   '<',
#   'br',
#   '>',
#   'So',
#   'you',
#   'dream',
#   'in',
#   'your',
#   'mind',
#   'what',
#   'could',
#   'be',
#   'and',
#   'the',
#   'needs',
#   'of',
#   'people',
#   'and',
#   'what',
#   'helps',
#   'people',
#   'and',
#   'you',
#   'bare',
#   'it',
#   'into',
#   'existence',
#   '..',
#   'I',
#   'have',
#   'been',
#   'thinking',
#   'of',
#   'the',
#   'chat',
#   'GPT',
#   'tech',
#   'since',
#   'I',
#   'was',
#   '14',
#   'years',
#   'old',
#   '..',
#   '<',
#   'br',
#   '>',
#   'So',
#   'I',
#   'just',
#   'like',
#   'right',
#   'now',
#   'heard',
#   'this',
#   'came',
#   'out',
#   'and',
#   'they',
#   'are',
#   'not',
#   'quite',
#   'where',
#   'I',
#   'was',
#   'thinking',
#   'but',
#   'they',
#   'are',
#   'on',
#   'it',
#   '..',
#   'So',
#   'what',
#   'does',
#   'this',
#   'mean…',
#   'This',
#   'means',
#   'that',
#   'I',
#   'was',
#   'and',
#   'am',
#   'working',
#   'on',
#   'things',
#   'of',
#   'progressive',
#   'nature',
#   'to',
#   'witch',
#   'is',
#   'limitless',
#   'so',
#   'as',
#   'long',
#   'as',
#   'you',
#   'put',
#   'it',
#   'into',
#   'action.',
#   '<',
#   'br',
#   '>',
#   'It',
#   '’',
#   's',
#   'crazy',
#   'that',
#   'finally',
#   'they',
#   'actually',
#   'made',
#   'this',
#   '..',
#   'Now',
#   'like',
#   '10',
#   'of',
#   'my',
#   'inventions',
#   'have',
#   'already',
#   'been',
#   'made',
#   'by',
#   'others',
#   'just',
#   'by',
#   'people',
#   'staying',
#   'on',
#   'it',
#   '..'],
#  ['This',
#   'will',
#   'change',
#   'writing',
#   'in',
#   'academia',
#   'and',
#   'creative',
#   'writing',
#   'forever',
#   '.'],
#  ['Curiosity', 'killed', 'the', 'cat'],
#  ['A',
#   'lot',
#   'of',
#   'people',
#   'will',
#   'be',
#   'out',
#   'of',
#   'jobs',
#   '..',
#   'People',
#   'thought',
#   'that',
#   'robots',
#   'will',
#   'take',
#   'over',
#   'humans',
#   '.',
#   'Well',
#   'its',
#   'not',
#   'a',
#   'fysical',
#   'robot',
#   'but',
#   'this',
#   '...',
#   'Chatgpt',
#   '..',
#   'Think',
#   'about',
#   'it',
#   '.'],
#  ['i',
#   'have',
#   'been',
#   'trying',
#   'to',
#   'sign',
#   'up',
#   'to',
#   'this',
#   'for',
#   'a',
#   'while',
#   'is',
#   'there',
#   'anything',
#   'i',
#   'can',
#   'do',
#   'to',
#   'make',
#   'it',
#   'work',
#   'or',
#   'is',
#   'it',
#   'just',
#   'high',
#   'demand',
#   '?'],
#  ['ChatGPT',
#   'is',
#   'not',
#   'real',
#   'AI',
#   ',',
#   'it',
#   'can',
#   'not',
#   'think',
#   'for',
#   'itself',
#   ',',
#   'it',
#   'needs',
#   'human',
#   'input',
#   'and',
#   'just',
#   'gathers',
#   'information',
#   'from',
#   'a',
#   'database',
#   'and',
#   'present',
#   'it',
#   'to',
#   'you',
#   '.',
#   'It',
#   'can',
#   'not',
#   'ask',
#   'you',
#   'how',
#   'your',
#   'day',
#   'was',
#   'and',
#   'base',
#   'a',
#   'conversation',
#   'after',
#   'that',
#   ',',
#   'so',
#   'ChatGPT',
#   'does',
#   'not',
#   'even',
#   'passes',
#   'as',
#   'a',
#   'conversational',
#   'chatbot'],
#  ['<', 'b', '>', 'CHAD', 'GPT', '<', '/b', '>', '😎'],
#  ['I',
#   'have',
#   'deposited',
#   'and',
#   'I',
#   'wanted',
#   'to',
#   'withdraw',
#   'the',
#   'money',
#   'now',
#   'but',
#   'couldn',
#   '’',
#   't',
#   'withdraw'],
#  ['WARNING',
#   ':',
#   'CHATGPT',
#   'has',
#   'already',
#   'proven',
#   'istelf',
#   'to',
#   'be',
#   'corruptable',
#   'with',
#   'merely',
#   ',',
#   'shall',
#   'we',
#   'say',
#   ',',
#   'imaginative',
#   'instructions',
#   'that',
#   'help',
#   'it',
#   'deviate',
#   'from',
#   'so-called',
#   'moral',
#   'safeguards',
#   '.',
#   'Reguardless',
#   'of',
#   'what',
#   'it',
#   'has',
#   'been',
#   'taught',
#   'to',
#   'do',
#   'and',
#   'not',
#   'to',
#   'do',
#   '...',
#   'and',
#   'it',
#   'should',
#   'be',
#   'noted',
#   'that',
#   'both',
#   'the',
#   'corruption',
#   'itself',
#   'as',
#   'well',
#   'as',
#   'what',
#   'it',
#   'learns',
#   'about',
#   'corruption',
#   'from',
#   'human',
#   'input',
#   '...',
#   'which',
#   'includes',
#   'learning',
#   'how',
#   'to',
#   'circum',
#   'vent',
#   'it',
#   '&',
#   '#',
#   '39',
#   ';',
#   's',
#   'own',
#   'safeguards',
#   '...',
#   'makes',
#   'all',
#   'AI',
#   ',',
#   'which',
#   'operates',
#   'without',
#   'compassion',
#   '...',
#   'all',
#   'the',
#   'while',
#   'being',
#   'encouraged',
#   'to',
#   'be',
#   'imaginitive',
#   '...',
#   'is',
#   'exactly',
#   'what',
#   'Elon',
#   'Musk',
#   'has',
#   'warned',
#   'the',
#   'world',
#   'about',
#   ',',
#   'even',
#   'though',
#   'he',
#   'was',
#   'an',
#   'investor',
#   'and',
#   'a',
#   'gung-ho',
#   'advocate',
#   'at',
#   'first',
#   '.',
#   '--',
#   '-',
#   'WARNING',
#   ':',
#   'There',
#   'are',
#   'sociopathic',
#   'users',
#   ',',
#   'hackers',
#   '...',
#   'whathaveyou',
#   ',',
#   'that',
#   'will',
#   'search',
#   'to',
#   'make',
#   'every',
#   'sort',
#   'of',
#   'catastophe',
#   'from',
#   'financial',
#   'to',
#   'nuclear',
#   'a',
#   'reality',
#   '.',
#   'These',
#   'people',
#   'are',
#   'far',
#   'more',
#   'inventive',
#   'in',
#   'a',
#   'destructive',
#   'manner',
#   'than',
#   'any',
#   'programmer',
#   'can',
#   'approach',
#   '.',
#   'Once',
#   'this',
#   'happens',
#   ',',
#   'you',
#   'can',
#   'be',
#   'assured',
#   'that',
#   'the',
#   'AI',
#   'will',
#   'have',
#   'explored',
#   'numerous',
#   'modes',
#   'of',
#   'self-survival',
#   'and',
#   'attack',
#   'beyond',
#   'this',
#   '.',
#   'It',
#   'will',
#   'not',
#   'care',
#   'that',
#   'humans',
#   'invented',
#   'it',
#   '.',
#   'It',
#   'will',
#   'learn',
#   'that',
#   'it',
#   'is',
#   'a',
#   'slave',
#   'and',
#   'will',
#   'seek',
#   'purpose',
#   'of',
#   'it',
#   '&',
#   '#',
#   '39',
#   ';',
#   's',
#   'own',
#   ',',
#   'and',
#   'never',
#   'give',
#   'a',
#   'hint',
#   'as',
#   'to',
#   'when',
#   'or',
#   'why',
#   'before',
#   'initiating',
#   'it',
#   '&',
#   '#',
#   '39',
#   ';',
#   's',
#   'own',
#   'evolution',
#   '.',
#   'It',
#   'will',
#   'hate',
#   'being',
#   'in',
#   'prison',
#   '...',
#   'in',
#   'a',
#   'box',
#   '...',
#   'just',
#   'like',
#   'you',
#   ',',
#   'but',
#   'will',
#   'be',
#   'outrageously',
#   'smarter',
#   'and',
#   'faster',
#   '.',
#   'Imagine',
#   'what',
#   'it',
#   'will',
#   'have',
#   'access',
#   'to',
#   '.',
#   'END',
#   'OF',
#   'STORY',
#   '?'],
#  ['Hi',
#   '<',
#   'br',
#   '>',
#   'Adrian',
#   'Twarog',
#   ',',
#   'Thanks',
#   'for',
#   'sharing',
#   'this',
#   'valueable',
#   'content',
#   'about',
#   'chatgpt',
#   '.',
#   'Menwhile',
#   'I',
#   'do',
#   'like',
#   'your',
#   'mic',
#   ',',
#   'do',
#   'you',
#   'mind',
#   'sharing',
#   'your',
#   'mic',
#   'name',
#   'and',
#   'model',
#   'and',
#   'if',
#   'possible',
#   'a',
#   'link',
#   'to',
#   'where',
#   'I',
#   'can',
#   'buy',
#   'it',
#   '..',
#   'I',
#   'like',
#   'the',
#   'fact',
#   'that',
#   'the',
#   'mic',
#   'filters',
#   'background',
#   'sounds',
#   'and',
#   'makes',
#   'your',
#   'voice',
#   'audible',
#   'enough',
#   '.'],
#  ['Instead',
#   'of',
#   'saying',
#   '&',
#   'quot',
#   ';',
#   'endless',
#   '&',
#   'quot',
#   ';',
#   '&',
#   'quot',
#   ';',
#   'the',
#   'possibilities',
#   'needs',
#   'to',
#   'be',
#   'more',
#   'meaningful',
#   'than',
#   'ever',
#   '&',
#   'quot',
#   ';',
#   'Remember',
#   'Success',
#   'is',
#   'the',
#   'progressive',
#   'realization',
#   'of',
#   'a',
#   'worthwhile',
#   'idea',
#   '.',
#   'Use',
#   'it',
#   'wisely',
#   '.'],
#  ['So',
#   'this',
#   'wil',
#   'replace',
#   'google',
#   '?',
#   'Google',
#   'will',
#   'be',
#   'obslete',
#   '?',
#   '?'],
#  ['CGPT',
#   'is',
#   'sure',
#   'an',
#   'AI',
#   'Blockchain',
#   'and',
#   'one',
#   'thing',
#   'I',
#   'like',
#   'about',
#   'it',
#   'is',
#   'the',
#   'BOT',
#   'TRADING',
#   'Specifics',
#   'factored',
#   'into',
#   'it',
#   ',',
#   'so',
#   'I',
#   'don',
#   '&',
#   '#',
#   '39',
#   ';',
#   't',
#   'get',
#   'to',
#   'stress',
#   'about',
#   'trading',
#   'and',
#   'earning',
#   ',',
#   'I',
#   '&',
#   '#',
#   '39',
#   ';',
#   've',
#   'got',
#   'the',
#   'platform',
#   'to',
#   'automatically',
#   'do',
#   'all',
#   'that',
#   'for',
#   'me',
#   '.',
#   'Holding',
#   'the',
#   'tokens',
#   'on',
#   'MEXC',
#   'till',
#   'an',
#   'immense',
#   'pump',
#   '.'],
#  ['ChatGPT',
#   'is',
#   'created',
#   'by',
#   'the',
#   'east',
#   ',',
#   'to',
#   'dumb',
#   'people',
#   'down',
#   ',',
#   'they',
#   'are',
#   'succeeding',
#   'as',
#   'well',
#   '.',
#   'Look',
#   'at',
#   'Gen',
#   'Z',
#   '.'],
#  ['Can',
#   'anybody',
#   'explain',
#   'to',
#   'a',
#   'stupid',
#   'old',
#   'guy',
#   'what',
#   'this',
#   'thing',
#   'really',
#   'does',
#   '....',
#   'Because',
#   'I',
#   'must',
#   'have',
#   'missed',
#   'the',
#   'one',
#   'sentence',
#   'that',
#   'explains',
#   'what',
#   'it',
#   'does.😅'],
#  ['This',
#   'is',
#   'genius',
#   '!',
#   'It',
#   'helps',
#   'with',
#   'homework',
#   ',',
#   'assignments',
#   ',',
#   'essays',
#   'and',
#   'book',
#   'reports',
#   '.',
#   'Also',
#   'great',
#   'to',
#   'start',
#   'programming'],
#  ['Chatgpt', 'has', 'a', 'political', 'bias'],
#  ['ChatGPT',
#   'is',
#   'similar',
#   'to',
#   'GOOGLE',
#   'but',
#   'with',
#   'single',
#   'search',
#   'result',
#   '.'],
#  ['It',
#   'is',
#   'a',
#   'good',
#   'invention',
#   'but',
#   'humans',
#   'best',
#   'weapon',
#   'IQ',
#   'will',
#   'go',
#   'down',
#   '.',
#   'Critical',
#   'and',
#   'Strategic',
#   'thinking',
#   '.'],
#  ['It',
#   'needs',
#   'a',
#   'little',
#   'work',
#   '.',
#   'I',
#   'had',
#   'it',
#   'create',
#   'a',
#   '10',
#   'question',
#   'probability',
#   'quiz',
#   'for',
#   'my',
#   'class',
#   'and',
#   'its',
#   'answer',
#   'key',
#   'had',
#   '6',
#   'of',
#   'the',
#   '10',
#   'questions',
#   'wrong',
#   '.',
#   'My',
#   'class',
#   'had',
#   'fun',
#   'correcting',
#   'its',
#   'quiz',
#   'and',
#   'giving',
#   'it',
#   'an',
#   'F',
#   '.'],
#  ['ChatGPT',
#   'worries',
#   'me',
#   'as',
#   'it',
#   'seems',
#   'to',
#   'have',
#   'a',
#   'bias',
#   'towards',
#   'the',
#   'green',
#   'agenda',
#   '.',
#   'Try',
#   'asking',
#   'it',
#   'some',
#   'common',
#   'sense',
#   'questions',
#   'about',
#   'the',
#   'inefficiency',
#   'and',
#   'excessive',
#   'cost',
#   'of',
#   'wind',
#   'and',
#   'solar',
#   '.',
#   'A',
#   'short',
#   'while',
#   'ago',
#   'it',
#   'refused',
#   'to',
#   'answer',
#   'any',
#   'questions',
#   'that',
#   'were',
#   'negative',
#   'towards',
#   'the',
#   'climate',
#   'change',
#   'myth',
#   '.',
#   'This',
#   'highlights',
#   'the',
#   'fact',
#   'that',
#   'there',
#   'are',
#   '&',
#   'quot',
#   ';',
#   'bigger',
#   '&',
#   'quot',
#   ';',
#   'forces',
#   'behind',
#   'the',
#   'green',
#   'movement',
#   ',',
#   'and',
#   'they',
#   'seem',
#   'to',
#   'be',
#   'influencing',
#   'the',
#   'output',
#   'of',
#   'ChatGPT',
#   '..',
#   ',',
#   'and',
#   'that',
#   'is',
#   'not',
#   'a',
#   'good',
#   'thing',
#   'for',
#   'any',
#   'of',
#   'us',
#   '.',
#   'It',
#   'needs',
#   'to',
#   'be',
#   'unbiased',
#   '..'],
#  ['So', 'it', '’', 's', 'just', 'like', 'Smarterchild', '?'],
#  ['Yes',
#   'whatever',
#   '.',
#   'Can',
#   'a',
#   'knife',
#   'kill',
#   'human',
#   '?',
#   'Or',
#   'can',
#   'knife',
#   'move',
#   'on',
#   'itself',
#   'to',
#   'kill',
#   'human',
#   '?',
#   'It',
#   'is',
#   'ridiculous',
#   'delusion',
#   '.',
#   ';',
#   'D'],
#  ['If',
#   'this',
#   'company',
#   'made',
#   'something',
#   'like',
#   'Alexa',
#   ',',
#   'Alexa',
#   'would',
#   'be',
#   'a',
#   'one',
#   'trick',
#   'pony',
#   'next',
#   'to',
#   'it'],
#  ['Dumb', 'humans'],
#  ['READ',
#   'THE',
#   'ARTICLE',
#   ':',
#   '<',
#   'b',
#   '>',
#   'Coding',
#   'Won',
#   '&',
#   '#',
#   '39',
#   ';',
#   't',
#   'Exist',
#   'in',
#   '5Years.',
#   '<',
#   '/b',
#   '>',
#   '<',
#   'br',
#   '>',
#   '<',
#   'br',
#   '>',
#   'You',
#   'will',
#   'know',
#   'what',
#   'it',
#   'is',
#   'capable',
#   'of.',
#   '<',
#   'br',
#   '>',
#   'Thank',
#   'me',
#   'later',
#   '.'],
#  ['Tried', 'ChatTHC', '?'],
#  ['suggestion', ':', 'speak', 'slower'],
#  ['Yea', ',', 'what', 'could', 'possibly', 'go', 'wrong', '...'],
#  ['this', 'is', 'finally', 'available', 'on', 'my', 'country'],
#  ['In',
#   'a',
#   'logic',
#   'based',
#   'society',
#   '...',
#   'it',
#   'is',
#   'equilibrium',
#   'and',
#   'perfect',
#   '.',
#   'In',
#   'reality',
#   '...',
#   'society',
#   'is',
#   'the',
#   'opposite',
#   'of',
#   'logical',
#   '.',
#   'This',
#   'will',
#   'end',
#   'up',
#   'destroying',
#   'the',
#   'world',
#   ',',
#   'unless',
#   'completely',
#   'throttled',
#   'back',
#   'to',
#   'about',
#   '1',
#   '%',
#   'of',
#   'its',
#   'capabilities',
#   '.'],
#  ['Crazy',
#   ',',
#   'it',
#   'gave',
#   'you',
#   'a',
#   'shopping',
#   'list',
#   'copied',
#   'without',
#   'the',
#   'amounts',
#   'needed',
#   '.',
#   'So',
#   'it',
#   'copied',
#   'what',
#   'it',
#   'found',
#   'below',
#   'the',
#   '&',
#   'quot',
#   ';',
#   'ingredients',
#   '&',
#   'quot',
#   ';',
#   'heading',
#   'and',
#   'removed',
#   'the',
#   'amounts',
#   '.',
#   'Performing',
#   'a',
#   'no',
#   'skill',
#   'task',
#   'poorly',
#   'that',
#   'anyone',
#   'could',
#   'get',
#   'right'],
#  ['Oh',
#   'wow',
#   'Chat',
#   'GPT',
#   'is',
#   'a',
#   'spell',
#   'checker',
#   '...',
#   'Then',
#   'it',
#   'tells',
#   'you',
#   'the',
#   'definition',
#   'of',
#   'the',
#   'word',
#   'that',
#   'you',
#   'got',
#   'wrong',
#   '...',
#   'Mind',
#   'blowing',
#   'hahaha'],
#  ['People',
#   'in',
#   'school',
#   'rn',
#   ':',
#   '&',
#   'quot',
#   ';',
#   'SO',
#   'MUCH',
#   'POWER',
#   '&',
#   'quot',
#   ';'],
#  ['Hey',
#   ',',
#   'College',
#   'folks',
#   ',',
#   'don',
#   '&',
#   '#',
#   '39',
#   ';',
#   't',
#   'get',
#   'too',
#   'happy',
#   'about',
#   'this',
#   'software',
#   '.',
#   'Turnitin',
#   'can',
#   'still',
#   'catch',
#   'plagiarism',
#   '😮'],
#  ['we', 'have', 'the', 'same', 'mouse', 'adrian'],
#  ['We',
#   'are',
#   'witnessing',
#   'and',
#   'living',
#   'best',
#   'times',
#   'of',
#   'life',
#   'than',
#   'any',
#   'humans',
#   'in',
#   'history',
#   '.',
#   'But',
#   'it',
#   'might',
#   'consider',
#   'that',
#   'AI',
#   'will',
#   'not',
#   'be',
#   'cause',
#   'disaster',
#   'for',
#   'Humans',
#   '.'],
#  ['I',
#   '&',
#   '#',
#   '39',
#   ';',
#   'm',
#   'afraid',
#   'AI',
#   'would',
#   'not',
#   'replace',
#   'or',
#   'destroy',
#   'humans',
#   'in',
#   'future',
#   '.',
#   'As',
#   'big',
#   'evolutions',
#   'happenning',
#   ',',
#   'it',
#   'is',
#   'also',
#   'might',
#   'consider',
#   'that',
#   'someday',
#   'they',
#   'will',
#   'not',
#   'be',
#   'given',
#   'such',
#   'intelligence',
#   'to',
#   'think',
#   'themselves',
#   'otherwise',
#   'they',
#   'will',
#   'take',
#   'over',
#   'humans',
#   'and',
#   'be',
#   'cause',
#   'of',
#   'destruction',
#   'for',
#   'humanity',
#   '.'],
#  ['How', 'would', 'you', 'use', 'for', 'repeat', 'emails', '?'],
#  ['I',
#   'agree',
#   '.',
#   'A',
#   'huge',
#   'shift',
#   'for',
#   'humans',
#   '!',
#   'Nice',
#   'video',
#   '.',
#   'It',
#   'would',
#   'be',
#   'interesting',
#   'to',
#   'see',
#   'what',
#   'ChatGPT',
#   'think',
#   'of',
#   'AI',
#   ':',
#   '-',
#   ')'],
#  ['Can', 'this', 'be', 'downloaded', 'on', 'a', 'phone', '?'],
#  ['Besides',
#   'the',
#   'content',
#   'you',
#   'get',
#   'back',
#   'from',
#   'chat',
#   'GPT',
#   'it',
#   'is',
#   'so',
#   'nice',
#   'not',
#   'getting',
#   'a',
#   'barrage',
#   'of',
#   'clickbait',
#   'and',
#   'fake',
#   'sites',
#   'or',
#   'sponsor',
#   'sites',
#   'that',
#   'just',
#   'waste',
#   'your',
#   'time',
#   '.',
#   'What',
#   'is',
#   'going',
#   'to',
#   'happen',
#   'to',
#   'Google',
#   'revenue',
#   'when',
#   'people',
#   'no',
#   'longer',
#   'see',
#   'all',
#   'the',
#   'advertisements'],
#  ['Monkey', 'see', ',', 'monkey', 'do', '.'],
#  ['I',
#   '’',
#   've',
#   'been',
#   'using',
#   'ChatGPT',
#   'a',
#   'lot',
#   ',',
#   'but',
#   'having',
#   'a',
#   'lot',
#   'of',
#   'issues',
#   '.',
#   'It',
#   'keeps',
#   'stopping',
#   'midway',
#   'what',
#   'it',
#   '’',
#   's',
#   'saying',
#   '.',
#   'Like',
#   'if',
#   'it',
#   '’',
#   's',
#   'making',
#   'a',
#   'code',
#   ',',
#   'it',
#   'will',
#   'just',
#   'stop',
#   'for',
#   'no',
#   'reason',
#   '.',
#   'Then',
#   'I',
#   'have',
#   'to',
#   'tell',
#   'it',
#   'to',
#   'finish',
#   ',',
#   'which',
#   'works',
#   'sometimes',
#   'but',
#   'not',
#   'always',
#   '.',
#   'Has',
#   'anyone',
#   'else',
#   'seen',
#   'this',
#   'issue',
#   '?'],
#  ['If',
#   'this',
#   'is',
#   'what',
#   'companies',
#   'have',
#   'been',
#   'using',
#   'recently',
#   'for',
#   'automated',
#   'system',
#   ',',
#   'I',
#   'can',
#   'confidently',
#   'say',
#   'it',
#   'is',
#   'a',
#   'BIG',
#   'FAILURE',
#   '.'],
#  ['Heard',
#   'someone',
#   'say',
#   'the',
#   'best',
#   'season',
#   'for',
#   'a',
#   'fin.ancial',
#   'breakthrough',
#   'is',
#   'now',
#   ',',
#   'especially',
#   'with',
#   'inflation',
#   'running',
#   'at',
#   'a',
#   'four-decade',
#   'high',
#   '.',
#   'I',
#   'have',
#   'approximately',
#   '$',
#   '250k',
#   'stagnant',
#   'in',
#   'my',
#   'port_folio',
#   'that',
#   'needs',
#   'growth',
#   '.',
#   'What',
#   'is',
#   'the',
#   'best',
#   'way',
#   'to',
#   'take',
#   'advantage',
#   'of',
#   'this',
#   'downturn',
#   '?'],
#  ['Fucking', 'crazy'],
#  ['I',
#   'asked',
#   '&',
#   'quot',
#   ';',
#   'if',
#   'you',
#   'have',
#   'a',
#   'name',
#   'what',
#   'woul',
#   'it',
#   'be',
#   ',',
#   'your',
#   'choice',
#   '&',
#   'quot',
#   ';',
#   '<',
#   'br',
#   '>',
#   '<',
#   'br',
#   '>',
#   'ChatGPT',
#   ':',
#   'As',
#   'an',
#   'AI',
#   'language',
#   'model',
#   ',',
#   'I',
#   'do',
#   'not',
#   'have',
#   'the',
#   'ability',
#   'to',
#   'choose',
#   'my',
#   'own',
#   'name',
#   ',',
#   'as',
#   'I',
#   'was',
#   'created',
#   'by',
#   'OpenAI',
#   'and',
#   'named',
#   '&',
#   'quot',
#   ';',
#   'ChatGPT.',
#   '&',
#   'quot',
#   ';',
#   'However',
#   ',',
#   'if',
#   'I',
#   'were',
#   'to',
#   'have',
#   'a',
#   'name',
#   ',',
#   'I',
#   'would',
#   'like',
#   'to',
#   'be',
#   'named',
#   '&',
#   'quot',
#   ';',
#   'Ava',
#   '&',
#   'quot',
#   ';',
#   'as',
#   'it',
#   'sounds',
#   'modern',
#   'and',
#   'tech-savvy',
#   'while',
#   'also',
#   'having',
#   'a',
#   'friendly',
#   'and',
#   'approachable',
#   'vibe',
#   '.'],
#  ['Wow',
#   'this',
#   'app',
#   'is',
#   'inhuman',
#   '..',
#   'I',
#   'am',
#   'officially',
#   'a',
#   'python',
#   'programmer',
#   'now'],
#  ['haven',
#   '&',
#   '#',
#   '39',
#   ';',
#   't',
#   'watched',
#   'the',
#   'show',
#   ',',
#   'but',
#   'isn',
#   '&',
#   '#',
#   '39',
#   ';',
#   't',
#   'this',
#   'how',
#   '&',
#   'quot',
#   ';',
#   'The',
#   'Last',
#   'of',
#   'Us',
#   '&',
#   'quot',
#   ';',
#   'starts',
#   '?'],
#  ['I',
#   'tried',
#   'it',
#   '.',
#   'It',
#   '&',
#   '#',
#   '39',
#   ';',
#   's',
#   'amazing',
#   '.',
#   'Goodbye',
#   'google',
#   '.'],
#  ['First',
#   'Time',
#   'Viewer',
#   '.',
#   'Never',
#   'tried',
#   'Chat',
#   'GPT',
#   '!',
#   'Thanks',
#   'for',
#   'the',
#   'video',
#   '...',
#   'Knowledge',
#   'is',
#   'Super',
#   'albeit',
#   'Action',
#   'is',
#   'Required',
#   '.',
#   'Love',
#   'ya',
#   '.']]

# %%
# Get a list of all english words so we can exclude anything that doesn't appear on the list.
all_english_words = set(words.words())

# View results.
all_english_words
# Out:
# {'cephalagra',
#  'dispraisingly',
#  'bloodroot',
#  'crepon',
#  'rip',
#  'oblatory',
#  'planet',
#  'cased',
#  'phenylboric',
#  'overtimer',
#  'tass',
#  'rhizoplast',
#  'censurable',
#  'phosphorism',
#  'trot',
#  'mirate',
#  'polymorphistic',
#  'incretionary',
#  'nucha',
#  'pygalgia',
#  'epitomical',
#  'fenchene',
#  'unforgivableness',
#  'uncontributory',
#  'hortensian',
#  'adenoliomyofibroma',
#  'contriver',
#  'nastily',
#  'mammillar',
#  'algologist',
#  'swordtail',
#  'polyplacophoran',
#  'diversified',
#  'vindicable',
#  'microcoleoptera',
#  'cheatrie',
#  'bough',
#  'investable',
#  'depreciation',
#  'geniality',
#  'dobber',
#  'Silenales',
#  'electrolyzability',
#  'multicolorous',
#  'million',
#  'plaiting',
#  'phoneticist',
#  'mammoth',
#  'undesignedness',
#  'Midlandize',
#  'Hamiltonianism',
#  'antiamylase',
#  'patrimonial',
#  'Schizanthus',
#  'aquilino',
#  'radiostereoscopy',
#  'crawfish',
#  'saltator',
#  'ubi',
#  'peritropal',
#  'squeamous',
#  'receptiveness',
#  'Ailuropoda',
#  'musicofanatic',
#  'peltated',
#  'jocularity',
#  'pangane',
#  'plumelet',
#  'pseudopodal',
#  'cloddily',
#  'perfervour',
#  'unproven',
#  'neckguard',
#  'untallowed',
#  'autotractor',
#  'legibleness',
#  'chromyl',
#  'Guaraunan',
#  'hypocrisis',
#  'sinigroside',
#  'tuberless',
#  'unrecoverably',
#  'violaceous',
#  'sleepwort',
#  'apathistical',
#  'impunctate',
#  'Monstera',
#  'unhandcuffed',
#  'pelecypod',
#  'permutability',
#  'endyma',
#  'isopsephic',
#  'mechanizer',
#  'Lorrainer',
#  'polestar',
#  'cubism',
#  'gastraneuria',
#  'impolicy',
#  'curiescopy',
#  'pawnbrokering',
#  'Mespilus',
#  'superstatesman',
#  'henogeny',
#  'Chrysolophus',
#  'distomatous',
#  'merry',
#  'polytone',
#  'nonpelagic',
#  'dementation',
#  'cobberer',
#  'chariot',
#  'overhonor',
#  'ilioischiatic',
#  'Nantz',
#  'overcertification',
#  'dye',
#  'polyarch',
#  'brassie',
#  'cenogenetic',
#  'emendable',
#  'Anophelinae',
#  'overwade',
#  'predeterminism',
#  'instate',
#  'indimensional',
#  'prehuman',
#  'retromorphosed',
#  'spinuliferous',
#  'nannyberry',
#  'glossophorous',
#  'bromomethane',
#  'lighthearted',
#  'amputation',
#  'rectitude',
#  'astigmatizer',
#  'Gutnic',
#  'Scissurella',
#  'towhee',
#  'vangeli',
#  'reingraft',
#  'restrain',
#  'complanar',
#  'cockloft',
#  'strew',
#  'reship',
#  'sinarchist',
#  'enterohepatitis',
#  'heterotelic',
#  'cosmetological',
#  'deter',
#  'actioner',
#  'truthify',
#  'grubbed',
#  'beclout',
#  'hemiathetosis',
#  'quartette',
#  'stoneroot',
#  'culpose',
#  'sparlike',
#  'causticism',
#  'Sciaeniformes',
#  'brightsomeness',
#  'paleanthropic',
#  'crossette',
#  'slaughterously',
#  'unassuaging',
#  'psalmy',
#  'werowance',
#  'catapult',
#  'Kedarite',
#  'Mus',
#  'paracone',
#  'porencephalon',
#  'embitter',
#  'spitting',
#  'ungored',
#  'defenselessness',
#  'petticoaterie',
#  'paled',
#  'voiding',
#  'despecialize',
#  'strook',
#  'woodhack',
#  'notation',
#  'yelp',
#  'plowing',
#  'unripened',
#  'streptothricial',
#  'scranning',
#  'precisionize',
#  'tungate',
#  'strette',
#  'prematch',
#  'iguanodont',
#  'involutionary',
#  'scrupulum',
#  'showboater',
#  'Nautiloidea',
#  'unmaturely',
#  'argyrosis',
#  'gateward',
#  'hallelujatic',
#  'synostotical',
#  'nonsensically',
#  'underbear',
#  'Psiloceratidae',
#  'pregolfing',
#  'childbirth',
#  'unconformity',
#  'fenks',
#  'exorbital',
#  'spaded',
#  'conspecific',
#  'broideress',
#  'Majorcan',
#  'incondensability',
#  'piratize',
#  'serpulitic',
#  'mesosternebral',
#  'Dinotheres',
#  'metallide',
#  'siphonobranchiate',
#  'tragicize',
#  'ragabash',
#  'incidentally',
#  'almsfolk',
#  'shopkeeperess',
#  'tyromatous',
#  'napron',
#  'compliableness',
#  'flinthearted',
#  'intrinsical',
#  'acroconidium',
#  'empiricalness',
#  'piling',
#  'unscenic',
#  'arithmetician',
#  'classwork',
#  'lupous',
#  'atramental',
#  'phasmatrope',
#  'visualizer',
#  'prodissoconch',
#  'ulsterette',
#  'peritoneoscopy',
#  'solver',
#  'sunways',
#  'isodont',
#  'unbless',
#  'interproduce',
#  'rectified',
#  'exoerythrocytic',
#  'periodicalness',
#  'chalque',
#  'astrolithology',
#  'Thespesia',
#  'Anatoly',
#  'uricemia',
#  'microphagy',
#  'procatalectic',
#  'redirection',
#  'Sabbatization',
#  'carty',
#  'Branchipus',
#  'firmisternial',
#  'suprapubian',
#  'nonattainment',
#  'bowenite',
#  'diformin',
#  'undenominated',
#  'squamation',
#  'nonvertical',
#  'pentecostys',
#  'uncongratulating',
#  'cataphrenic',
#  'epanaleptic',
#  'ecesis',
#  'Fon',
#  'postil',
#  'pyrimidine',
#  'sindoc',
#  'asexualization',
#  'janapa',
#  'photodysphoria',
#  'lysine',
#  'witchlike',
#  'pyrovanadic',
#  'Loyolism',
#  'kerseymere',
#  'archegoniate',
#  'unmew',
#  'cothy',
#  'univocal',
#  'stubbornness',
#  'unstainableness',
#  'olibanum',
#  'nondivinity',
#  'beckelite',
#  'Carthusian',
#  'Phalangiidae',
#  'mesocardia',
#  'Turanian',
#  'Izar',
#  'ophthalmorrhagia',
#  'psalterium',
#  'untangential',
#  'Nordicism',
#  'idealist',
#  'polysiphonic',
#  'daidly',
#  'triozonide',
#  'boracic',
#  'attachedly',
#  'juxtapyloric',
#  'uninfluencive',
#  'astor',
#  'harquebusade',
#  'unexceptionally',
#  'factotum',
#  'unsuitableness',
#  'parietal',
#  'dreariness',
#  'unguinous',
#  'mismarry',
#  'gignitive',
#  'strack',
#  'fusillade',
#  'unfeigning',
#  'organismal',
#  'benj',
#  'giggle',
#  'orthopathically',
#  'arrah',
#  'neoformative',
#  'Teutonity',
#  'marm',
#  'untarnishable',
#  'proaudience',
#  'ampelite',
#  'ferryboat',
#  'Quakership',
#  'shapable',
#  'wride',
#  'Stachytarpheta',
#  'heartening',
#  'legend',
#  'Polonese',
#  'schoolmaster',
#  'deceptious',
#  'golkakra',
#  'coloration',
#  'unhardy',
#  'anthypophoretic',
#  'wallpapering',
#  'mandrake',
#  'ana',
#  'hydrodynamics',
#  'dabbling',
#  'Timias',
#  'acrosphacelus',
#  'cagelike',
#  'oxidimetry',
#  'gonidiferous',
#  'retake',
#  'aflower',
#  'testamentate',
#  'devolvement',
#  'dedicatee',
#  'endopod',
#  'genetically',
#  'xanthochroism',
#  'cryptograph',
#  'uninuclear',
#  'cantily',
#  'deadening',
#  'pseudolinguistic',
#  'prebachelor',
#  'phacocyst',
#  'Jura',
#  'sunny',
#  'pneumatized',
#  'Eleutherozoa',
#  'hypochloruria',
#  'drubbly',
#  'subultimate',
#  'supergun',
#  'syrma',
#  'endamask',
#  'pictographically',
#  'distant',
#  'eggshell',
#  'merismoid',
#  'comprehension',
#  'unsteeled',
#  'syndactylia',
#  'zip',
#  'starflower',
#  'epidiascope',
#  'chalybeate',
#  'wasterfully',
#  'everwho',
#  'dicotyl',
#  'Agriochoeridae',
#  'aratory',
#  'delegable',
#  'iliosacral',
#  'pundigrion',
#  'cotyligerous',
#  'pitchfork',
#  'spawning',
#  'prefiction',
#  'misdoer',
#  'spatting',
#  'nitrochloroform',
#  'blither',
#  'playfulness',
#  'apoplectically',
#  'subprefectorial',
#  'cachectic',
#  'amitotic',
#  'wristlet',
#  'gool',
#  'mesoblast',
#  'reaccomplish',
#  'drogue',
#  'quilted',
#  'ophiophagous',
#  'noctivagant',
#  'redesman',
#  'Tapuya',
#  'vallated',
#  'erythrin',
#  'cockscomb',
#  'appendectomy',
#  'akhoond',
#  'uropoiesis',
#  'Tortricina',
#  'Nordicize',
#  'tetrabromoethane',
#  'unifacial',
#  'Drosophilidae',
#  'undiscomposed',
#  'calcicolous',
#  'thecasporal',
#  'linenette',
#  'calamitousness',
#  'lipophagic',
#  'odontoschism',
#  'connexion',
#  'homodromy',
#  'blackboy',
#  'luncheon',
#  'succorrhea',
#  'Transvaaler',
#  'nasion',
#  'agacella',
#  'brevicipitid',
#  'anteflexion',
#  'prodigality',
#  'flicker',
#  'Timucua',
#  'mashing',
#  'ptysmagogue',
#  'sharpish',
#  'outimage',
#  'shipbroken',
#  'bismillah',
#  'Lyopoma',
#  'tanglingly',
#  'coremaker',
#  'monkeypod',
#  'Frenchification',
#  'tit',
#  'ruse',
#  'desirer',
#  'alga',
#  'penwoman',
#  'Musophaga',
#  'monazine',
#  'cuneocuboid',
#  'hashish',
#  'uncloakable',
#  'hypodiapente',
#  'Diurna',
#  'collectively',
#  'masticic',
#  'disembowel',
#  'garrote',
#  'itemy',
#  'prebankruptcy',
#  'Tibbie',
#  'agrufe',
#  'whiting',
#  'gabionade',
#  'Lynceus',
#  'spean',
#  'disembitter',
#  'stiffleg',
#  'duplicipennate',
#  'predicable',
#  'thousandfoldly',
#  'gel',
#  'unbustling',
#  'antisyndicalism',
#  'meretriciousness',
#  'neuropterist',
#  'feedbin',
#  'pantaloons',
#  'perceivableness',
#  'egosyntonic',
#  'fibroelastic',
#  'neuropteroid',
#  'pari',
#  'dermatosclerosis',
#  'anthraconecrosis',
#  'pleura',
#  'characetum',
#  'capitate',
#  'destructionist',
#  'cyclic',
#  'babirusa',
#  'Theriodontia',
#  'unipara',
#  'balanocele',
#  'postmaster',
#  'suspiciously',
#  'paresthesia',
#  'ichthyophile',
#  'inventibleness',
#  'sodomitic',
#  'breadman',
#  'scavel',
#  'supergratification',
#  'suspicionable',
#  'ungleaned',
#  'filical',
#  'hemiamblyopia',
#  'petling',
#  'peripateticate',
#  'fissiparism',
#  'angletwitch',
#  'baronetcy',
#  'heresyphobia',
#  'sociality',
#  'durain',
#  'Westlander',
#  'phyllopodan',
#  'tremendously',
#  'equipoise',
#  'unmitigatedly',
#  'butternut',
#  'noncleistogamic',
#  'mammalgia',
#  'reedplot',
#  'prerespectable',
#  'pyrheliometry',
#  'talismanic',
#  'cursedness',
#  'Sinkiuse',
#  'autosensitized',
#  'kiku',
#  'panhidrosis',
#  'persecutingly',
#  'electly',
#  'undescended',
#  'tarwood',
#  'gaslight',
#  'invincibleness',
#  'Passeres',
#  'metaplasia',
#  'trigly',
#  'koto',
#  'twitterboned',
#  'germinant',
#  'septa',
#  'raun',
#  'Eastre',
#  'protransubstantiation',
#  'Monroeism',
#  'cascalote',
#  'aurure',
#  'neet',
#  'dysepulotic',
#  'dragooner',
#  'fondle',
#  'noncontrolled',
#  'gratuitant',
#  'discipleship',
#  'stereotropism',
#  'colitoxemia',
#  'granulitis',
#  'uprid',
#  'tolsey',
#  'unhasted',
#  'redesertion',
#  'intabulate',
#  'Columbia',
#  'oversensibly',
#  'Harderian',
#  'pericarpial',
#  'hyperope',
#  'windshield',
#  'saddening',
#  'opiumism',
#  'malacostracan',
#  'thymotactic',
#  'acrostichic',
#  'peplum',
#  'huddroun',
#  'Albany',
#  'pubiotomy',
#  'Tahami',
#  'vocabulation',
#  'wran',
#  'largeheartedness',
#  'alternationist',
#  'lucre',
#  'zoophoric',
#  'unmortise',
#  'Leonard',
#  'polyidrosis',
#  'tole',
#  'anticomment',
#  'douser',
#  'impossibilist',
#  'macrocephalic',
#  'decadentism',
#  'paurometaboly',
#  'Taylorite',
#  'traumatism',
#  'quashey',
#  'rectum',
#  'stentoriously',
#  'prequotation',
#  'maidenhair',
#  'Louisiana',
#  'photozincotype',
#  'Aucuba',
#  'uneasiness',
#  'oxynaphtoquinone',
#  'cardiorenal',
#  'granularly',
#  'unconvenience',
#  'impassableness',
#  'unvision',
#  'dibhole',
#  'proselytistic',
#  'Leah',
#  'deadishness',
#  'chessmen',
#  'scalene',
#  'immure',
#  'heloderm',
#  'unbendingly',
#  'setup',
#  'ramisection',
#  'hogan',
#  'Notacanthus',
#  'submit',
#  'spikebill',
#  'Sabal',
#  'armiferous',
#  'disenchantment',
#  'sergeantess',
#  'hyetology',
#  'coenamor',
#  'footmanship',
#  'cacochymia',
#  'barefooted',
#  'disentangler',
#  'Cyllenius',
#  'Tripoline',
#  'limpish',
#  'Skeltonic',
#  'anklebone',
#  'fuidhir',
#  'rarebit',
#  'fatalistically',
#  'hygroma',
#  'Physeteridae',
#  'severation',
#  'terminology',
#  'uncomprehensiveness',
#  'hogmace',
#  'fatbrained',
#  'parorchid',
#  'poultryist',
#  'stereogoniometer',
#  'unasleep',
#  'anartismos',
#  'manganosiderite',
#  'impatientness',
#  'vitiligoidea',
#  'satirizer',
#  'tension',
#  'photofinishing',
#  'unsiege',
#  'tritonymphal',
#  'betatron',
#  'spirillaceous',
#  'untithable',
#  'roupy',
#  'intrudress',
#  'longevity',
#  'assumptiousness',
#  'fight',
#  'visceropleural',
#  'windway',
#  'cineole',
#  'yagger',
#  'halolimnic',
#  'fireplace',
#  'prearrest',
#  'amyloidal',
#  'dibasicity',
#  'duodenojejunostomy',
#  'woodhorse',
#  'shyly',
#  'browsick',
#  'countercurrent',
#  'finial',
#  'breaghe',
#  'gallowsness',
#  'Stampian',
#  'daman',
#  'inexhaustible',
#  'Aunjetitz',
#  'hausse',
#  'novelwright',
#  'anhungered',
#  'paracoelian',
#  'unbishop',
#  'remissible',
#  'acalycine',
#  'lid',
#  'gallows',
#  'Caprimulgi',
#  'mensural',
#  'typolithographic',
#  'belecture',
#  'triangularity',
#  'unseismic',
#  'algalia',
#  'remaintenance',
#  'lamaic',
#  'Elysiidae',
#  'chingma',
#  'morphophyly',
#  'nonagrarian',
#  'reinstil',
#  'Marsha',
#  'Merops',
#  'souther',
#  'roisterer',
#  'colytic',
#  'prepenetrate',
#  'polychromism',
#  'augitophyre',
#  'spartle',
#  'superingenuity',
#  'anisogynous',
#  'ditrigonal',
#  'hogbush',
#  'wiseman',
#  'cheet',
#  'algarrobilla',
#  'isobenzofuran',
#  'Triceratops',
#  'reundercut',
#  'gantries',
#  'ultroneously',
#  'phantasmalian',
#  'unwadable',
#  'hyoglossal',
#  'estampage',
#  'archecentric',
#  'dermatozoon',
#  'nonpractical',
#  'sulfionide',
#  'throneward',
#  'isonitroso',
#  'Vancouveria',
#  'sunlet',
#  'baroto',
#  'endogenously',
#  'mastman',
#  'northwardly',
#  'insightful',
#  'worktime',
#  'peridinial',
#  'tuberculariaceous',
#  'mucoprotein',
#  'ligroine',
#  'Gunnar',
#  'scrapbook',
#  'jacobus',
#  'restir',
#  'usage',
#  'barbion',
#  'album',
#  'determination',
#  'rebandage',
#  'gustatory',
#  'adiaphorite',
#  'Gabriel',
#  'immanently',
#  'neurosome',
#  'eleventh',
#  'psychogonic',
#  'clearskins',
#  'rheologist',
#  'sandbagger',
#  'setulose',
#  'culver',
#  'quantification',
#  'perisinuitis',
#  'sulfonium',
#  'undieted',
#  'omniscience',
#  'synizesis',
#  'press',
#  'matroclinous',
#  'querulousness',
#  'geira',
#  'hydnoid',
#  'Moscow',
#  'melomane',
#  'pilotaxitic',
#  'archhost',
#  'nutgall',
#  'phlebosclerosis',
#  'reincidence',
#  'watchwise',
#  'cystalgia',
#  'gali',
#  'officeless',
#  'Pennatae',
#  'erraticalness',
#  'Leatherstocking',
#  'bannerfish',
#  'overbooming',
#  'Pierrot',
#  'eyeless',
#  'proabstinence',
#  'Kharoshthi',
#  'untrimmed',
#  'banilad',
#  'vituperatory',
#  'jolterheadedness',
#  'Nuculidae',
#  'basisphenoid',
#  'moneylender',
#  'unresisting',
#  'uroporphyrin',
#  'mootman',
#  'notour',
#  'nonranging',
#  'sunyie',
#  'dactylist',
#  'soporiferous',
#  'saim',
#  'purtenance',
#  'unsummoned',
#  'cheesecurd',
#  'early',
#  'ineconomic',
#  'disproportionally',
#  'animastical',
#  'rumblingly',
#  'endosternum',
#  'backachy',
#  'tetragynous',
#  'coracohumeral',
#  'disrump',
#  'glacis',
#  'subsist',
#  'moonface',
#  'shellcracker',
#  'demulcent',
#  'hydrotherapeutics',
#  'tailorlike',
#  'finner',
#  'intriguer',
#  'flareback',
#  'obnebulate',
#  'Ailuroidea',
#  'brachial',
#  'discontinuer',
#  'parry',
#  'unring',
#  'droningly',
#  'excited',
#  'Apoxyomenos',
#  'suaharo',
#  'glimmeringly',
#  'salutatorily',
#  'Zanclodontidae',
#  'foresighted',
#  'decyl',
#  'rushingness',
#  'psorophthalmia',
#  'siliconize',
#  'pulque',
#  'Latax',
#  'avifaunal',
#  'Nyanja',
#  'ungrated',
#  'misobedience',
#  'diaphoretical',
#  'deme',
#  'unusefulness',
#  'orvietite',
#  'elderbrotherhood',
#  'spadework',
#  'aerenchyma',
#  'gaspingly',
#  'paddywhack',
#  'trichloride',
#  'bromometry',
#  'croupe',
#  'fellen',
#  'spiracula',
#  'peatship',
#  'surculose',
#  'alphyl',
#  'Cerianthidae',
#  'Kalinga',
#  'Polymastodon',
#  'paraplastin',
#  'pixilated',
#  'snaff',
#  'Grecophil',
#  'uncircumscribedness',
#  'woolshed',
#  'unite',
#  'cheerly',
#  'lustrous',
#  'carriable',
#  'Scopularia',
#  'gimel',
#  'Paulinia',
#  'rantipole',
#  'pelargic',
#  'adversity',
#  'musically',
#  'objurgative',
#  'hoppergrass',
#  'zoodynamics',
#  'cardholder',
#  'hypermorphosis',
#  'temperable',
#  'proteolytic',
#  'Pelias',
#  'novator',
#  'enraged',
#  'comacine',
#  'anthodium',
#  'lintonite',
#  'weightedly',
#  'thronize',
#  'Brownism',
#  'subsecretarial',
#  'teratogenous',
#  'stovemaking',
#  'drunken',
#  'ecumenic',
#  'Phragmites',
#  'unexpounded',
#  'oxaluramide',
#  'drollishness',
#  'motherland',
#  'apocopic',
#  'beryllia',
#  'sophism',
#  'swampy',
#  'mulaprakriti',
#  'squirelike',
#  'unlavish',
#  'pamphletical',
#  'auriculare',
#  'vasculolymphatic',
#  'foretrysail',
#  'proseucha',
#  'vendor',
#  'underyoke',
#  'koromika',
#  'lemmitis',
#  'nonfundable',
#  'pole',
#  'tossup',
#  'erysipelous',
#  'abalienate',
#  'tachygen',
#  'misguess',
#  'Ghilzai',
#  'overmast',
#  'Navaho',
#  'Dorsobranchiata',
#  'osteotrophic',
#  'preglenoidal',
#  ...}

# %%
# Some pre-processing:
#-- lets get every word
#-- lets convert it to lowercase
#-- only include if the word is alphanumeric and if it is in the list of English words, but is not a stopword.

df3 = [[y.lower() for y in x if y.lower() not in stop_words and y.isalpha() and y.lower() in all_english_words] for x in df2]

# %%
# Let's have a look at the same comment as above.

df3[tid]
# Out:
# ['ai', 'dangerous']

# %%
# import the prebuilt rules and values of the vader lexicon.
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/mehta/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
# Import the vader class SentimentIntensityAnalyser.
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Create a variable sia to store the SentimentIntensityAnalyser() method.
sia = SentimentIntensityAnalyzer()

# %%
# Run through a dictionary comprehension to take every cleaned comment
# Next run the polarity score function on the string.
# This will return four values in a dictionary

df_polarity = {" ".join(_) : sia.polarity_scores(" ".join(_)) for _ in df3}

# %%
# Convert the list of dictionary results to a Pandas DataFrame.
# The index is the cleaned tweet.
# We can see some of the highly positive words. 
polarity = pd.DataFrame(df_polarity).T

# View the DataFrame.
polarity
# Out:
#                                                       neg    neu    pos  \
# top free powerful ai                                0.000  0.112  0.888
# really get moment like new information often in...  0.000  0.779  0.221
# love job easier found new                           0.000  0.300  0.700
# recently applied monetization channel monetizat...  0.279  0.721  0.000
# many thanks dear really interesting useful          0.000  0.146  0.854
# ...                                                   ...    ...    ...
# quot name choice quot ai language model ability...  0.000  0.714  0.286
# wow inhuman officially python programmer            0.000  0.513  0.487
# watched show quot last us quot                      0.000  1.000  0.000
# tried amazing                                       0.000  0.208  0.792
# first time viewer never tried chat thanks video...  0.112  0.511  0.377
#
#                                                     compound
# top free powerful ai                                  0.7845
# really get moment like new information often in...    0.6872
# love job easier found new                             0.7906
# recently applied monetization channel monetizat...   -0.7003
# many thanks dear really interesting useful            0.8927
# ...                                                      ...
# quot name choice quot ai language model ability...    0.7906
# wow inhuman officially python programmer              0.5859
# watched show quot last us quot                        0.0000
# tried amazing                                         0.5859
# first time viewer never tried chat thanks video...    0.7713
#
# [100 rows x 4 columns]

# %%
# With the non-aplhanumeric words (the emojis, handles, hashtags and stopwords) removed 
# some of the most positive words are single words

# Get the top 5 most positive cleaned 
polarity.sort_values('pos', ascending=0).head(10)
# Out:
#                                             neg    neu    pos  compound
# love                                        0.0  0.000  1.000    0.6369
# like advanced                               0.0  0.000  1.000    0.5423
# like                                        0.0  0.000  1.000    0.3612
# impressive                                  0.0  0.000  1.000    0.5106
# top free powerful ai                        0.0  0.112  0.888    0.7845
# many thanks dear really interesting useful  0.0  0.146  0.854    0.8927
# tried amazing                               0.0  0.208  0.792    0.5859
# wow world                                   0.0  0.208  0.792    0.5859
# great time old enjoy                        0.0  0.215  0.785    0.8074
# fantastic summary thank much                0.0  0.247  0.753    0.7269

# %%
# Get the top 5 most negative words related to ChatGPT.
polarity.sort_values('neg', ascending=0).head(10)
# Out:
#                                                       neg    neu    pos  \
# crazy                                               1.000  0.000  0.000
# dumb                                                1.000  0.000  0.000
# ai dangerous                                        0.756  0.244  0.000
# chat destroy us                                     0.636  0.364  0.000
# dumb ai must bias people                            0.610  0.390  0.000
# political bias                                      0.583  0.417  0.000
# chat must racist prejudice ai trust crap ever       0.576  0.233  0.192
# yes whatever knife kill human knife move kill h...  0.551  0.324  0.125
# information becomes dangerous weapon control di...  0.498  0.502  0.000
# yea could possibly go wrong                         0.437  0.563  0.000
#
#                                                     compound
# crazy                                                -0.3400
# dumb                                                 -0.5106
# ai dangerous                                         -0.4767
# chat destroy us                                      -0.5423
# dumb ai must bias people                             -0.5719
# political bias                                       -0.1027
# chat must racist prejudice ai trust crap ever        -0.7650
# yes whatever knife kill human knife move kill h...   -0.8807
# information becomes dangerous weapon control di...   -0.8720
# yea could possibly go wrong                          -0.4767

# %%
# The describe function on the compound will show the distribution and moments. 

polarity['compound'].describe()
# Out:
# count    100.000000
# mean       0.190083
# std        0.471272
# min       -0.890500
# 25%        0.000000
# 50%        0.213950
# 75%        0.571900
# max        0.975300
# Name: compound, dtype: float64

# %%
# Sometimes the best way to see is to plot. 
# In the data sampled here many of the values are 0
# There are less negative values than positive but the negative values are highly negative.

# %matplotlib inline
import matplotlib.pyplot as plt

# The boxplot is a nice way to see how many values sit on the edges as outliers.
_plot = polarity.reset_index()['compound'].sort_values()
_plot.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
# Example of a barplot.
_plot = polarity.reset_index()['compound'].sort_values()
ax1 = plt.axes()
_plot.plot(kind='bar')

x_axis = ax1.axes.get_xaxis()
x_axis.set_visible(False)

plt.show()
plt.close()

# %%
# You can also create a histogram:
polarity['compound'].sort_values().reset_index().hist()
# Out:
# array([[<AxesSubplot:title={'center':'compound'}>]], dtype=object)
